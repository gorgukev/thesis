# %% [markdown]
# #Examensarbete: **Kevin Görgü**

# %% [markdown]
# # **Del 1: Datainsamling av matchmetadata**

# %% [markdown]
# ## Syfte
# Samla in grundläggande matchinformation från Premier League säsongerna 2015-2025 via Football-API.
#
# ## Vad görs här?
# 1. **API-anslutning**: Kopplar upp mot Football-API med din API-nyckel
# 2. **Liga och säsongsval**: Definierar vilka ligor och år som ska samlas in (Premier League ID=39)
# 3. **Säsongbestämning**: Automatisk beräkning av aktuell säsong baserat på datum (augusti-juli)
# 4. **Datahämtning**: För varje säsong hämtas:
#    - Fixture ID (matchens unika identifierare)
#    - Datum och tid
#    - Lag (hemma/borta) med ID och namn
#    - Halvtidsresultat och slutresultat
#    - Vinnare (True/False för varje lag)
#
# ## Utdata
# - **DataFrame**: `df_meta` med 3800 matcher
# - **Kolumner skapade**:
#   - `total_goals_ht`: Totalt antal mål vid halvtid
#   - `total_goals_ft`: Totalt antal mål vid slutsignal
#   - `fulltime_over_2_5`: Binär klassificering (1 = över 2.5 mål, 0 = under)
#
# ## Viktig anteckning om dataläckage
# Vid detta steg samlas resultatet in, men det kommer INTE användas direkt i modellen.
# Endast `fulltime_over_2_5` används som target variable (y). All annan information
# omvandlas till rullande medelvärden i senare steg för att undvika dataläckage.
#
# ## Fil som skapas
# - `fixture_meta_data.csv` - Grunddata för alla 3800 matcher

# %%
import http.client
import json
import pandas as pd
from datetime import datetime




"""
League IDs, add league IDs to collect more data
Premier League = 39
"""
league_ids = [39]

# Year list 2015-2025
start_year = 2015
end_year = 2025
years = list(range(start_year, end_year))

"""
Determine the correct season year (August - July season). To determine weather or not its a new season.
 - 2025 april = season 2024
 - 2025 august = season 2026
"""
today = datetime.today()
current_season = today.year if today.month >= 8 else today.year - 1


#  API connection settings
API_KEY = "YOUR API KEY" #OBS API KEY EXPIRED

conn = http.client.HTTPSConnection("v3.football.api-sports.io")
headers = {
    'x-rapidapi-host': "v3.football.api-sports.io",
    'x-rapidapi-key': API_KEY
}

print(current_season)
# Out:
# 2025

# %%
all_rows = []

for league in league_ids:
    for season in years:
        endpoint = f"/fixtures?league={league}&season={season}"
        conn.request("GET", endpoint, headers=headers)
        res = conn.getresponse()
        data = res.read()
        api_response = json.loads(data.decode("utf-8"))

        # (optional) be nice to the API / avoid rate limits
        # time.sleep(0.25)

        for match in api_response.get("response", []):
            fixture = match["fixture"]
            league_info = match["league"]
            teams = match["teams"]
            score = match["score"]

            all_rows.append({
                "fixture_id": fixture["id"],
                "date": fixture["date"],
                "season": league_info["season"],
                "home_team_id": teams["home"]["id"],
                "home_team_name": teams["home"]["name"],
                "away_team_id": teams["away"]["id"],
                "away_team_name": teams["away"]["name"],
                "ht_home_goals": (score.get("halftime") or {}).get("home"),
                "ht_away_goals": (score.get("halftime") or {}).get("away"),
                "ft_home_goals": (score.get("fulltime") or {}).get("home"),
                "ft_away_goals": (score.get("fulltime") or {}).get("away"),
                "home_winner": teams["home"].get("winner"),
                "away_winner": teams["away"].get("winner"),
            })

df = pd.DataFrame(all_rows)

# Possible fixture features
"""
"fixture_id": fixture["id"],
"date": fixture["date"],
"referee": fixture.get("referee"),
"venue_name": fixture["venue"].get("name"),
"venue_city": fixture["venue"].get("city"),
"status": fixture["status"].get("long"),

"league_id": league_info["id"],
"league_name": league_info["name"],
"league_country": league_info["country"],
"season": league_info["season"],
"round": league_info["round"],

"home_team_id": teams["home"]["id"],
"home_team_name": teams["home"]["name"],
"away_team_id": teams["away"]["id"],
"away_team_name": teams["away"]["name"],

"home_goals": goals.get("home"),
"away_goals": goals.get("away"),

"ht_home_goals": score["halftime"].get("home"),
"ht_away_goals": score["halftime"].get("away"),
"ft_home_goals": score["fulltime"].get("home"),
"ft_away_goals": score["fulltime"].get("away"),

"home_winner": teams["home"].get("winner"),
"away_winner": teams["away"].get("winner")
"""
# Out:
# '\n"fixture_id": fixture["id"],\n"date": fixture["date"],\n"referee": fixture.get("referee"),\n"venue_name": fixture["venue"].get("name"),\n"venue_city": fixture["venue"].get("city"),\n"status": fixture["status"].get("long"),\n\n"league_id": league_info["id"],\n"league_name": league_info["name"],\n"league_country": league_info["country"],\n"season": league_info["season"],\n"round": league_info["round"],\n\n"home_team_id": teams["home"]["id"],\n"home_team_name": teams["home"]["name"],\n"away_team_id": teams["away"]["id"],\n"away_team_name": teams["away"]["name"],\n\n"home_goals": goals.get("home"),\n"away_goals": goals.get("away"),\n\n"ht_home_goals": score["halftime"].get("home"),\n"ht_away_goals": score["halftime"].get("away"),\n"ft_home_goals": score["fulltime"].get("home"),\n"ft_away_goals": score["fulltime"].get("away"),\n\n"home_winner": teams["home"].get("winner"),\n"away_winner": teams["away"].get("winner")\n'

# %%
df_meta = pd.DataFrame(all_rows)

# %%
import numpy as np

# Ensure numeric (API sometimes returns None)
goal_cols = [
    "ht_home_goals", "ht_away_goals",
    "ft_home_goals", "ft_away_goals"
]

df_meta[goal_cols] = df_meta[goal_cols].apply(pd.to_numeric, errors="coerce").fillna(0)

# Half-time total goals
df_meta["total_goals_ht"] = df_meta["ht_home_goals"] + df_meta["ht_away_goals"]

# Full-time total goals
df_meta["total_goals_ft"] = df_meta["ft_home_goals"] + df_meta["ft_away_goals"]

# Full-time Over 2.5 goals (1 = yes, 0 = no)
df_meta["fulltime_over_2_5"] = (df_meta["total_goals_ft"] > 2.5).astype(int)

# %%
df = df_meta

# %%
# ---------- Derived metrics ----------
df["btts"] = ((df["ft_home_goals"] > 0) & (df["ft_away_goals"] > 0)).astype(int)
df["second_half_goals"] = df["total_goals_ft"] - df["total_goals_ht"]

# ---------- Class balance ----------
class_balance = (
    df["fulltime_over_2_5"]
    .value_counts(normalize=True)
    .rename("percent") * 100
).round(2)

# ---------- EDA summary ----------
eda_summary = {
    "Total matches": len(df),

    "Over 2.5 (%)": round(df["fulltime_over_2_5"].mean() * 100, 2),
    "Under 2.5 (%)": round((1 - df["fulltime_over_2_5"].mean()) * 100, 2),

    "Avg FT goals": round(df["total_goals_ft"].mean(), 2),
    "Avg HT goals": round(df["total_goals_ht"].mean(), 2),

    "Games w/ HT goal (%)": round((df["total_goals_ht"] > 0).mean() * 100, 2),
    "Games w/ 2H goal (%)": round((df["second_half_goals"] > 0).mean() * 100, 2),
    "Goals in both halves (%)": round(
        ((df["total_goals_ht"] > 0) & (df["second_half_goals"] > 0)).mean() * 100, 2
    ),

    "BTTS (%)": round(df["btts"].mean() * 100, 2),
    "0–0 games (%)": round(
        ((df["ft_home_goals"] == 0) & (df["ft_away_goals"] == 0)).mean() * 100, 2
    ),
}

# ---------- Print results ----------
print("\n=== CLASS BALANCE (Over 2.5) ===")
print(class_balance)

print("\n=== EDA SUMMARY ===")
print(pd.Series(eda_summary))

print("\n=== FULL-TIME GOAL DISTRIBUTION (%) ===")
print(
    (df["total_goals_ft"]
     .value_counts(normalize=True)
     .sort_index() * 100)
    .round(2)
)
# Out:
# === CLASS BALANCE (Over 2.5) ===
# fulltime_over_2_5
# 1    54.18
# 0    45.82
# Name: percent, dtype: float64
#
# === EDA SUMMARY ===
# Total matches               3800.00
# Over 2.5 (%)                  54.18
# Under 2.5 (%)                 45.82
# Avg FT goals                   2.83
# Avg HT goals                   1.26
# Games w/ HT goal (%)          71.82
# Games w/ 2H goal (%)          80.24
# Goals in both halves (%)      58.26
# BTTS (%)                      52.34
# 0–0 games (%)                  6.21
# dtype: float64
#
# === FULL-TIME GOAL DISTRIBUTION (%) ===
# total_goals_ft
# 0     6.21
# 1    16.03
# 2    23.58
# 3    22.08
# 4    16.74
# 5     9.11
# 6     3.79
# 7     1.74
# 8     0.42
# 9     0.32
# Name: proportion, dtype: float64

# %%
df.to_csv("fixture_meta_data.csv", index=False)

# %%
df.tail()
# Out:
#       fixture_id                       date  season  home_team_id  \
# 3795     1208396  2025-05-25T15:00:00+00:00    2024            40
# 3796     1208400  2025-05-25T15:00:00+00:00    2024            41
# 3797     1208401  2025-05-25T15:00:00+00:00    2024            47
# 3798     1208395  2025-05-25T15:00:00+00:00    2024            57
# 3799     1208399  2025-05-25T15:00:00+00:00    2024            65
#
#          home_team_name  away_team_id  away_team_name  ht_home_goals  \
# 3795          Liverpool            52  Crystal Palace              0
# 3796        Southampton            42         Arsenal              0
# 3797          Tottenham            51        Brighton              1
# 3798            Ipswich            48        West Ham              0
# 3799  Nottingham Forest            49         Chelsea              0
#
#       ht_away_goals  ft_home_goals  ft_away_goals home_winner away_winner  \
# 3795              1              1              1        None        None
# 3796              1              1              2       False        True
# 3797              0              1              4       False        True
# 3798              1              1              3       False        True
# 3799              0              0              1       False        True
#
#       total_goals_ht  total_goals_ft  fulltime_over_2_5  btts  \
# 3795               1               2                  0     1
# 3796               1               3                  1     1
# 3797               1               5                  1     1
# 3798               1               4                  1     1
# 3799               0               1                  0     0
#
#       second_half_goals
# 3795                  1
# 3796                  2
# 3797                  4
# 3798                  3
# 3799                  1

# %% [markdown]
# # **Del 2: Hämta detaljerad målstatistik**

# %% [markdown]
# ## Syfte
# För varje match, hämta exakt tidpunkt (minut) när varje mål gjordes.
#
# ## Varför behövs detta?
# Enligt GoalStatistics analys är sannolikheten för över 2.5 mål:
# - **~40%** om mål görs i minut 0-15
# - **~16%** om inget mål görs i första halvlek
#
# Detta gör tidiga mål till en kritisk prediktor som bör ingå i modellen.
#
# ## Vad görs här?
# 1. **Funktion: `fetch_goal_events_once()`**
#    - Tar emot lista med fixture_id från Del 1
#    - För varje match: hämtar alla "Goal"-events från API
#    - Extraherar minuttal för varje mål
#
# 2. **Hantering av tilläggstid**
#    - Minut kan vara "90+5" → parsas till minut 90
#
# 3. **Smart cachning**
#    - Om filen redan finns → hoppar över API-anrop
#    - Sparar tid och API-calls vid omkörning
#
# ## Tekniska detaljer
# - **Rate limiting**: 0.3 sekunder väntetid mellan anrop (undvik API-begränsningar)
# - **Felhantering**: Skippar matcher med JSON-fel
# - **Progress tracking**: Visar [X/3800] för varje match
#
# ## Fil som skapas
# - `goals_prem_2015_2024.csv` med kolumner:
#   - `fixture_id`: Matchens ID
#   - `team_id`: Vilket lag som gjorde målet
#   - `team_name`: Lagets namn
#   - `minute`: Vilken minut målet gjordes (ex: "22" eller "90+3")
#
# ## OBS: API-begränsning
# Football-API har gräns på 100 anrop/dag (gratis tier). För 3800 matcher
# behövs premium-prenumeration ELLER flera dagar av datainsamling.

# %% [markdown]
# ## **Vad gör funktionen?** (api_get_with_retries)
#
# `api_get_with_retries` är en säker wrapper runt ett HTTP GET-anrop som gör API-hämtning robust.
#
# Den:
# - kontrollerar alltid HTTP-status (`res.status`)
# - retry:ar automatiskt vid nätverksfel
# - retry:ar vid **429 (rate limit)** och **500–599 (serverfel)**
# - använder **exponentiell backoff + jitter**
# - fångar trasiga eller tomma JSON-svar
# - hanterar API-fel som returneras i payload (`"errors"`)
# - loggar tydligt alla problem så de märks direkt
# - avbryter efter ett max antal försök och returnerar `None`
#
# Resultat:
# Stabil och felsäker API-hämtning som inte kraschar vid tillfälliga fel eller instabila API:er.

# %%
import os
import time
import json
import random
import http.client
import pandas as pd


def api_get_with_retries(
    host,
    endpoint,
    headers,
    fixture_id,
    max_retries=5,
    base_sleep=0.7,
    timeout_s=30,
):
    """
    Robust GET wrapper:
    - checks HTTP status
    - retries on 429 and 5xx with exponential backoff + jitter
    - retries on network errors + JSON decode errors
    - prints enough info to notice problems
    """
    for attempt in range(1, max_retries + 1):
        conn = http.client.HTTPSConnection(host, timeout=timeout_s)
        status = None
        data = None

        try:
            conn.request("GET", endpoint, headers=headers)
            res = conn.getresponse()
            status = res.status
            data = res.read()
        except Exception as e:
            print(f"❌ Network error for fixture {fixture_id} (attempt {attempt}/{max_retries}): {e}")
        finally:
            try:
                conn.close()
            except Exception as e_close:
                print(f"⚠️ Failed to close connection (ignored): {e_close}")

        # If request failed before we got anything
        if status is None or data is None:
            sleep = base_sleep * (2 ** (attempt - 1)) + random.uniform(0, 0.25)
            print(f"⏳ Retrying fixture {fixture_id} after {sleep:.2f}s (no response)")
            time.sleep(sleep)
            continue

        # Retry on rate limit or server errors
        if status == 429 or (500 <= status <= 599):
            snippet = data[:200]
            sleep = base_sleep * (2 ** (attempt - 1)) + random.uniform(0, 0.25)
            print(
                f"⚠️ HTTP {status} for fixture {fixture_id} (attempt {attempt}/{max_retries}). "
                f"Retrying in {sleep:.2f}s. Body start: {snippet!r}"
            )
            time.sleep(sleep)
            continue

        # Non-retriable HTTP errors
        if status != 200:
            snippet = data[:200]
            print(f"❌ HTTP {status} for fixture {fixture_id}. Body start: {snippet!r}")
            return None

        # Parse JSON
        try:
            payload = json.loads(data.decode("utf-8"))
        except json.JSONDecodeError as e:
            snippet = data[:200]
            sleep = base_sleep * (2 ** (attempt - 1)) + random.uniform(0, 0.25)
            print(
                f"❌ JSON decode failed for fixture {fixture_id} (attempt {attempt}/{max_retries}): {e}. "
                f"Retrying in {sleep:.2f}s. Body start: {snippet!r}"
            )
            time.sleep(sleep)
            continue

        # API-level error field (if present)
        if isinstance(payload, dict) and payload.get("errors"):
            sleep = base_sleep * (2 ** (attempt - 1)) + random.uniform(0, 0.25)
            print(
                f"⚠️ API errors for fixture {fixture_id} (attempt {attempt}/{max_retries}): "
                f"{payload.get('errors')}. Retrying in {sleep:.2f}s."
            )
            time.sleep(sleep)
            continue

        return payload

    print(f"❌ Giving up fixture {fixture_id} after {max_retries} attempts.")
    return None

# %%
def fetch_goal_events_once(
    api_key,
    df_fixtures=None,
    fixtures_path="../raw_data_files/fixtures_metadata.csv",
    save_path="goals_prem_2015_2024.csv",
    sleep_s=0.3,
    exclude_penalties=False,
    exclude_own_goals=False,
):
    # ----------------------------
    # Load fixture IDs
    # ----------------------------
    if df_fixtures is not None:
        fixture_ids = pd.unique(df_fixtures["fixture_id"])
        print(f"📊 Using in-memory DataFrame: {len(fixture_ids)} fixtures")
    else:
        df_fixtures = pd.read_csv(fixtures_path)
        fixture_ids = pd.unique(df_fixtures["fixture_id"])
        print(f"📊 Loaded fixtures from CSV: {len(fixture_ids)} fixtures")

    # ----------------------------
    # Ensure folder + CSV exist
    # ----------------------------
    os.makedirs(os.path.dirname(save_path) or ".", exist_ok=True)

    if not os.path.exists(save_path):
        pd.DataFrame(columns=["fixture_id", "team_id", "team_name", "minute"]).to_csv(save_path, index=False)
        print(f"🆕 Created CSV → {save_path}")

    # ----------------------------
    # Checkpoint to resume ALL fixtures (including 0-goal matches)
    # ----------------------------
    checkpoint_path = save_path + ".done"
    if not os.path.exists(checkpoint_path):
        with open(checkpoint_path, "w", encoding="utf-8") as f:
            f.write("")
        print(f"🆕 Created checkpoint → {checkpoint_path}")

    completed = set()
    try:
        with open(checkpoint_path, "r", encoding="utf-8") as f:
            for line in f:
                line = line.strip()
                if line:
                    try:
                        completed.add(int(line))
                    except ValueError:
                        completed.add(line)
    except Exception as e:
        print(f"❌ Failed to read checkpoint for resume: {e}")
        completed = set()

    print(f"🔁 Resuming: {len(completed)} fixtures already processed")

    headers = {
        "x-rapidapi-host": "v3.football.api-sports.io",
        "x-rapidapi-key": api_key,
    }

    total = len(fixture_ids)

    for i, fixture_id in enumerate(fixture_ids, 1):
        # Skip if already completed
        if fixture_id in completed:
            continue

        print(f"[{i}/{total}] 📥 Fetching goals for fixture {fixture_id}")

        endpoint = f"/fixtures?id={fixture_id}"
        payload = api_get_with_retries(
            host="v3.football.api-sports.io",
            endpoint=endpoint,
            headers=headers,
            fixture_id=fixture_id,
            max_retries=5,
            base_sleep=0.7,
            timeout_s=30,
        )

        # If request ultimately failed, do NOT mark completed (so we can retry next run)
        if payload is None:
            print(f"❌ Skipping fixture {fixture_id} (request failed). Will retry on next run.")
            time.sleep(sleep_s)
            continue

        resp = payload.get("response", [])
        if not resp:
            # This is a successful call but no match data came back.
            # We mark completed to avoid infinite loops, but we PRINT so you notice.
            print(f"⚠️ Empty response for fixture {fixture_id} (marked completed).")
            try:
                with open(checkpoint_path, "a", encoding="utf-8") as f:
                    f.write(str(fixture_id) + "\n")
                completed.add(fixture_id)
            except Exception as e:
                print(f"❌ Failed to write checkpoint for fixture {fixture_id}: {e}")
            time.sleep(sleep_s)
            continue

        match = resp[0]
        fx_id = match.get("fixture", {}).get("id", fixture_id)
        events = match.get("events", []) or []

        rows = []

        for ev in events:
            if ev.get("type") != "Goal":
                continue

            detail = (ev.get("detail") or "").lower()
            if exclude_penalties and "penalty" in detail:
                continue
            if exclude_own_goals and "own goal" in detail:
                continue

            team = ev.get("team", {}) or {}
            t = ev.get("time", {}) or {}
            elapsed = t.get("elapsed")
            extra = t.get("extra")

            minute = elapsed if extra is None else f"{elapsed}+{extra}"

            rows.append(
                {
                    "fixture_id": fx_id,
                    "team_id": team.get("id"),
                    "team_name": team.get("name"),
                    "minute": minute,
                }
            )

        # ----------------------------
        # Append immediately (goals CSV)
        # ----------------------------
        if rows:
            pd.DataFrame(rows).to_csv(save_path, mode="a", header=False, index=False)

        # ----------------------------
        # Mark fixture completed in checkpoint (ALWAYS, even if 0 goals)
        # ----------------------------
        try:
            with open(checkpoint_path, "a", encoding="utf-8") as f:
                f.write(str(fixture_id) + "\n")
            completed.add(fixture_id)
        except Exception as e:
            print(f"❌ Failed to write checkpoint for fixture {fixture_id}: {e}")

        time.sleep(sleep_s)

    print(f"✅ Goal fetch complete → {save_path}")
    return pd.read_csv(save_path)

# %%
    fetch_goal_events_once(
        api_key=API_KEY,
        fixtures_path="/content/fixture_meta_data.csv",
        save_path="goals_prem_2015_2024.csv",
        sleep_s=0.3,
        exclude_penalties=False,
        exclude_own_goals=False,
    )
# Out:
# 📊 Loaded fixtures from CSV: 3800 fixtures
# 🆕 Created checkpoint → goals_prem_2015_2024.csv.done
# 🔁 Resuming: 0 fixtures already processed
# [1/3800] 📥 Fetching goals for fixture 192297
# [2/3800] 📥 Fetching goals for fixture 192298
# [3/3800] 📥 Fetching goals for fixture 192301
# [4/3800] 📥 Fetching goals for fixture 192300
# [5/3800] 📥 Fetching goals for fixture 192299
# [6/3800] 📥 Fetching goals for fixture 192302
# [7/3800] 📥 Fetching goals for fixture 192303
# [8/3800] 📥 Fetching goals for fixture 192304
# [9/3800] 📥 Fetching goals for fixture 192305
# [10/3800] 📥 Fetching goals for fixture 192306
# [11/3800] 📥 Fetching goals for fixture 192307
# [12/3800] 📥 Fetching goals for fixture 192308
# [13/3800] 📥 Fetching goals for fixture 192313
# [14/3800] 📥 Fetching goals for fixture 192312
# [15/3800] 📥 Fetching goals for fixture 192309
# [16/3800] 📥 Fetching goals for fixture 192310
# [17/3800] 📥 Fetching goals for fixture 192311
# [18/3800] 📥 Fetching goals for fixture 192314
# [19/3800] 📥 Fetching goals for fixture 192315
# [20/3800] 📥 Fetching goals for fixture 192316
# [21/3800] 📥 Fetching goals for fixture 192317
# [22/3800] 📥 Fetching goals for fixture 192322
# [23/3800] 📥 Fetching goals for fixture 192319
# [24/3800] 📥 Fetching goals for fixture 192318
# [25/3800] 📥 Fetching goals for fixture 192320
# [26/3800] 📥 Fetching goals for fixture 192321
# [27/3800] 📥 Fetching goals for fixture 192323
# [28/3800] 📥 Fetching goals for fixture 192325
# [29/3800] 📥 Fetching goals for fixture 192324
# [30/3800] 📥 Fetching goals for fixture 192326
# [31/3800] 📥 Fetching goals for fixture 192327
# [32/3800] 📥 Fetching goals for fixture 192329
# [33/3800] 📥 Fetching goals for fixture 192333
# [34/3800] 📥 Fetching goals for fixture 192328
# [35/3800] 📥 Fetching goals for fixture 192331
# [36/3800] 📥 Fetching goals for fixture 192330
# [37/3800] 📥 Fetching goals for fixture 192332
# [38/3800] 📥 Fetching goals for fixture 192334
# [39/3800] 📥 Fetching goals for fixture 192335
# [40/3800] 📥 Fetching goals for fixture 192336
# [41/3800] 📥 Fetching goals for fixture 192337
# [42/3800] 📥 Fetching goals for fixture 192342
# [43/3800] 📥 Fetching goals for fixture 192341
# [44/3800] 📥 Fetching goals for fixture 192339
# [45/3800] 📥 Fetching goals for fixture 192340
# [46/3800] 📥 Fetching goals for fixture 192338
# [47/3800] 📥 Fetching goals for fixture 192343
# [48/3800] 📥 Fetching goals for fixture 192344
# [49/3800] 📥 Fetching goals for fixture 192345
# [50/3800] 📥 Fetching goals for fixture 192346
# [51/3800] 📥 Fetching goals for fixture 192347
# [52/3800] 📥 Fetching goals for fixture 192351
# [53/3800] 📥 Fetching goals for fixture 192350
# [54/3800] 📥 Fetching goals for fixture 192352
# [55/3800] 📥 Fetching goals for fixture 192349
# [56/3800] 📥 Fetching goals for fixture 192348
# [57/3800] 📥 Fetching goals for fixture 192353
# [58/3800] 📥 Fetching goals for fixture 192354
# [59/3800] 📥 Fetching goals for fixture 192356
# [60/3800] 📥 Fetching goals for fixture 192355
# [61/3800] 📥 Fetching goals for fixture 192357
# [62/3800] 📥 Fetching goals for fixture 192362
# [63/3800] 📥 Fetching goals for fixture 192359
# [64/3800] 📥 Fetching goals for fixture 192363
# [65/3800] 📥 Fetching goals for fixture 192358
# [66/3800] 📥 Fetching goals for fixture 192361
# [67/3800] 📥 Fetching goals for fixture 192360
# [68/3800] 📥 Fetching goals for fixture 192364
# [69/3800] 📥 Fetching goals for fixture 192365
# [70/3800] 📥 Fetching goals for fixture 192366
# [71/3800] 📥 Fetching goals for fixture 192367
# [72/3800] 📥 Fetching goals for fixture 192371
# [73/3800] 📥 Fetching goals for fixture 192369
# [74/3800] 📥 Fetching goals for fixture 192370
# [75/3800] 📥 Fetching goals for fixture 192368
# [76/3800] 📥 Fetching goals for fixture 192372
# [77/3800] 📥 Fetching goals for fixture 192373
# [78/3800] 📥 Fetching goals for fixture 192374
# [79/3800] 📥 Fetching goals for fixture 192375
# [80/3800] 📥 Fetching goals for fixture 192376
# [81/3800] 📥 Fetching goals for fixture 192377
# [82/3800] 📥 Fetching goals for fixture 192380
# [83/3800] 📥 Fetching goals for fixture 192381
# [84/3800] 📥 Fetching goals for fixture 192378
# [85/3800] 📥 Fetching goals for fixture 192379
# [86/3800] 📥 Fetching goals for fixture 192383
# [87/3800] 📥 Fetching goals for fixture 192382
# [88/3800] 📥 Fetching goals for fixture 192384
# [89/3800] 📥 Fetching goals for fixture 192385
# [90/3800] 📥 Fetching goals for fixture 192386
# [91/3800] 📥 Fetching goals for fixture 192388
# [92/3800] 📥 Fetching goals for fixture 192387
# [93/3800] 📥 Fetching goals for fixture 192389
# [94/3800] 📥 Fetching goals for fixture 192391
# [95/3800] 📥 Fetching goals for fixture 192390
# [96/3800] 📥 Fetching goals for fixture 192392
# [97/3800] 📥 Fetching goals for fixture 192393
# [98/3800] 📥 Fetching goals for fixture 192394
# [99/3800] 📥 Fetching goals for fixture 192395
# [100/3800] 📥 Fetching goals for fixture 192396
# [101/3800] 📥 Fetching goals for fixture 192397
# [102/3800] 📥 Fetching goals for fixture 192402
# [103/3800] 📥 Fetching goals for fixture 192403
# [104/3800] 📥 Fetching goals for fixture 192401
# [105/3800] 📥 Fetching goals for fixture 192400
# [106/3800] 📥 Fetching goals for fixture 192399
# [107/3800] 📥 Fetching goals for fixture 192398
# [108/3800] 📥 Fetching goals for fixture 192404
# [109/3800] 📥 Fetching goals for fixture 192405
# [110/3800] 📥 Fetching goals for fixture 192406
# [111/3800] 📥 Fetching goals for fixture 192407
# [112/3800] 📥 Fetching goals for fixture 192412
# [113/3800] 📥 Fetching goals for fixture 192411
# [114/3800] 📥 Fetching goals for fixture 192408
# [115/3800] 📥 Fetching goals for fixture 192410
# [116/3800] 📥 Fetching goals for fixture 192409
# [117/3800] 📥 Fetching goals for fixture 192413
# [118/3800] 📥 Fetching goals for fixture 192414
# [119/3800] 📥 Fetching goals for fixture 192415
# [120/3800] 📥 Fetching goals for fixture 192416
# [121/3800] 📥 Fetching goals for fixture 192417
# [122/3800] 📥 Fetching goals for fixture 192421
# [123/3800] 📥 Fetching goals for fixture 192423
# [124/3800] 📥 Fetching goals for fixture 192419
# [125/3800] 📥 Fetching goals for fixture 192422
# [126/3800] 📥 Fetching goals for fixture 192418
# [127/3800] 📥 Fetching goals for fixture 192420
# [128/3800] 📥 Fetching goals for fixture 192424
# [129/3800] 📥 Fetching goals for fixture 192425
# [130/3800] 📥 Fetching goals for fixture 192426
# [131/3800] 📥 Fetching goals for fixture 192427
# [132/3800] 📥 Fetching goals for fixture 192429
# [133/3800] 📥 Fetching goals for fixture 192428
# [134/3800] 📥 Fetching goals for fixture 192431
# [135/3800] 📥 Fetching goals for fixture 192430
# [136/3800] 📥 Fetching goals for fixture 192432
# [137/3800] 📥 Fetching goals for fixture 192433
# [138/3800] 📥 Fetching goals for fixture 192434
# [139/3800] 📥 Fetching goals for fixture 192436
# [140/3800] 📥 Fetching goals for fixture 192435
# [141/3800] 📥 Fetching goals for fixture 192437
# [142/3800] 📥 Fetching goals for fixture 192443
# [143/3800] 📥 Fetching goals for fixture 192440
# [144/3800] 📥 Fetching goals for fixture 192438
# [145/3800] 📥 Fetching goals for fixture 192441
# [146/3800] 📥 Fetching goals for fixture 192442
# [147/3800] 📥 Fetching goals for fixture 192439
# [148/3800] 📥 Fetching goals for fixture 192444
# [149/3800] 📥 Fetching goals for fixture 192445
# [150/3800] 📥 Fetching goals for fixture 192446
# [151/3800] 📥 Fetching goals for fixture 192447
# [152/3800] 📥 Fetching goals for fixture 192449
# [153/3800] 📥 Fetching goals for fixture 192450
# [154/3800] 📥 Fetching goals for fixture 192448
# [155/3800] 📥 Fetching goals for fixture 192451
# [156/3800] 📥 Fetching goals for fixture 192452
# [157/3800] 📥 Fetching goals for fixture 192453
# [158/3800] 📥 Fetching goals for fixture 192455
# [159/3800] 📥 Fetching goals for fixture 192454
# [160/3800] 📥 Fetching goals for fixture 192456
# [161/3800] 📥 Fetching goals for fixture 192460
# [162/3800] 📥 Fetching goals for fixture 192462
# [163/3800] 📥 Fetching goals for fixture 192459
# [164/3800] 📥 Fetching goals for fixture 192461
# [165/3800] 📥 Fetching goals for fixture 192457
# [166/3800] 📥 Fetching goals for fixture 192458
# [167/3800] 📥 Fetching goals for fixture 192463
# [168/3800] 📥 Fetching goals for fixture 192464
# [169/3800] 📥 Fetching goals for fixture 192465
# [170/3800] 📥 Fetching goals for fixture 192466
# [171/3800] 📥 Fetching goals for fixture 192467
# [172/3800] 📥 Fetching goals for fixture 192468
# [173/3800] 📥 Fetching goals for fixture 192469
# [174/3800] 📥 Fetching goals for fixture 192470
# [175/3800] 📥 Fetching goals for fixture 192472
# [176/3800] 📥 Fetching goals for fixture 192471
# [177/3800] 📥 Fetching goals for fixture 192474
# [178/3800] 📥 Fetching goals for fixture 192473
# [179/3800] 📥 Fetching goals for fixture 192475
# [180/3800] 📥 Fetching goals for fixture 192476
# [181/3800] 📥 Fetching goals for fixture 192481
# [182/3800] 📥 Fetching goals for fixture 192479
# [183/3800] 📥 Fetching goals for fixture 192480
# [184/3800] 📥 Fetching goals for fixture 192478
# [185/3800] 📥 Fetching goals for fixture 192477
# [186/3800] 📥 Fetching goals for fixture 192483
# [187/3800] 📥 Fetching goals for fixture 192482
# [188/3800] 📥 Fetching goals for fixture 192484
# [189/3800] 📥 Fetching goals for fixture 192485
# [190/3800] 📥 Fetching goals for fixture 192486
# [191/3800] 📥 Fetching goals for fixture 192487
# [192/3800] 📥 Fetching goals for fixture 192493
# [193/3800] 📥 Fetching goals for fixture 192490
# [194/3800] 📥 Fetching goals for fixture 192489
# [195/3800] 📥 Fetching goals for fixture 192492
# [196/3800] 📥 Fetching goals for fixture 192491
# [197/3800] 📥 Fetching goals for fixture 192488
# [198/3800] 📥 Fetching goals for fixture 192494
# [199/3800] 📥 Fetching goals for fixture 192495
# [200/3800] 📥 Fetching goals for fixture 192496
# [201/3800] 📥 Fetching goals for fixture 192499
# [202/3800] 📥 Fetching goals for fixture 192498
# [203/3800] 📥 Fetching goals for fixture 192497
# [204/3800] 📥 Fetching goals for fixture 192503
# [205/3800] 📥 Fetching goals for fixture 192504
# [206/3800] 📥 Fetching goals for fixture 192501
# [207/3800] 📥 Fetching goals for fixture 192502
# [208/3800] 📥 Fetching goals for fixture 192500
# [209/3800] 📥 Fetching goals for fixture 192505
# [210/3800] 📥 Fetching goals for fixture 192506
# [211/3800] 📥 Fetching goals for fixture 192507
# [212/3800] 📥 Fetching goals for fixture 192512
# [213/3800] 📥 Fetching goals for fixture 192510
# [214/3800] 📥 Fetching goals for fixture 192511
# [215/3800] 📥 Fetching goals for fixture 192509
# [216/3800] 📥 Fetching goals for fixture 192508
# [217/3800] 📥 Fetching goals for fixture 192513
# [218/3800] 📥 Fetching goals for fixture 192514
# [219/3800] 📥 Fetching goals for fixture 192515
# [220/3800] 📥 Fetching goals for fixture 192516
# [221/3800] 📥 Fetching goals for fixture 192517
# [222/3800] 📥 Fetching goals for fixture 192521
# [223/3800] 📥 Fetching goals for fixture 192520
# [224/3800] 📥 Fetching goals for fixture 192522
# [225/3800] 📥 Fetching goals for fixture 192523
# [226/3800] 📥 Fetching goals for fixture 192518
# [227/3800] 📥 Fetching goals for fixture 192519
# [228/3800] 📥 Fetching goals for fixture 192524
# [229/3800] 📥 Fetching goals for fixture 192525
# [230/3800] 📥 Fetching goals for fixture 192526
# [231/3800] 📥 Fetching goals for fixture 192530
# [232/3800] 📥 Fetching goals for fixture 192528
# [233/3800] 📥 Fetching goals for fixture 192527
# [234/3800] 📥 Fetching goals for fixture 192531
# [235/3800] 📥 Fetching goals for fixture 192529
# [236/3800] 📥 Fetching goals for fixture 192533
# [237/3800] 📥 Fetching goals for fixture 192532
# [238/3800] 📥 Fetching goals for fixture 192534
# [239/3800] 📥 Fetching goals for fixture 192535
# [240/3800] 📥 Fetching goals for fixture 192536
# [241/3800] 📥 Fetching goals for fixture 192537
# [242/3800] 📥 Fetching goals for fixture 192543
# [243/3800] 📥 Fetching goals for fixture 192541
# [244/3800] 📥 Fetching goals for fixture 192542
# [245/3800] 📥 Fetching goals for fixture 192540
# [246/3800] 📥 Fetching goals for fixture 192539
# [247/3800] 📥 Fetching goals for fixture 192538
# [248/3800] 📥 Fetching goals for fixture 192544
# [249/3800] 📥 Fetching goals for fixture 192545
# [250/3800] 📥 Fetching goals for fixture 192546
# [251/3800] 📥 Fetching goals for fixture 192547
# [252/3800] 📥 Fetching goals for fixture 192549
# [253/3800] 📥 Fetching goals for fixture 192551
# [254/3800] 📥 Fetching goals for fixture 192550
# [255/3800] 📥 Fetching goals for fixture 192552
# [256/3800] 📥 Fetching goals for fixture 192548
# [257/3800] 📥 Fetching goals for fixture 192553
# [258/3800] 📥 Fetching goals for fixture 192554
# [259/3800] 📥 Fetching goals for fixture 192555
# [260/3800] 📥 Fetching goals for fixture 192556
# [261/3800] 📥 Fetching goals for fixture 192557
# [262/3800] 📥 Fetching goals for fixture 192559
# [263/3800] 📥 Fetching goals for fixture 192560
# [264/3800] 📥 Fetching goals for fixture 192561
# [265/3800] 📥 Fetching goals for fixture 192558
# [266/3800] 📥 Fetching goals for fixture 192562
# [267/3800] 📥 Fetching goals for fixture 192563
# [268/3800] 📥 Fetching goals for fixture 192564
# [269/3800] 📥 Fetching goals for fixture 192570
# [270/3800] 📥 Fetching goals for fixture 192571
# [271/3800] 📥 Fetching goals for fixture 192569
# [272/3800] 📥 Fetching goals for fixture 192567
# [273/3800] 📥 Fetching goals for fixture 192568
# [274/3800] 📥 Fetching goals for fixture 192572
# [275/3800] 📥 Fetching goals for fixture 192573
# [276/3800] 📥 Fetching goals for fixture 192574
# [277/3800] 📥 Fetching goals for fixture 192576
# [278/3800] 📥 Fetching goals for fixture 192575
# [279/3800] 📥 Fetching goals for fixture 192577
# [280/3800] 📥 Fetching goals for fixture 192579
# [281/3800] 📥 Fetching goals for fixture 192582
# [282/3800] 📥 Fetching goals for fixture 192583
# [283/3800] 📥 Fetching goals for fixture 192581
# [284/3800] 📥 Fetching goals for fixture 192578
# [285/3800] 📥 Fetching goals for fixture 192580
# [286/3800] 📥 Fetching goals for fixture 192584
# [287/3800] 📥 Fetching goals for fixture 192585
# [288/3800] 📥 Fetching goals for fixture 192586
# [289/3800] 📥 Fetching goals for fixture 192587
# [290/3800] 📥 Fetching goals for fixture 192589
# [291/3800] 📥 Fetching goals for fixture 192588
# [292/3800] 📥 Fetching goals for fixture 192590
# [293/3800] 📥 Fetching goals for fixture 192591
# [294/3800] 📥 Fetching goals for fixture 192597
# [295/3800] 📥 Fetching goals for fixture 192600
# [296/3800] 📥 Fetching goals for fixture 192601
# [297/3800] 📥 Fetching goals for fixture 192598
# [298/3800] 📥 Fetching goals for fixture 192599
# [299/3800] 📥 Fetching goals for fixture 192602
# [300/3800] 📥 Fetching goals for fixture 192604
# [301/3800] 📥 Fetching goals for fixture 192603
# [302/3800] 📥 Fetching goals for fixture 192605
# [303/3800] 📥 Fetching goals for fixture 192606
# [304/3800] 📥 Fetching goals for fixture 192607
# [305/3800] 📥 Fetching goals for fixture 192609
# [306/3800] 📥 Fetching goals for fixture 192612
# [307/3800] 📥 Fetching goals for fixture 192608
# [308/3800] 📥 Fetching goals for fixture 192610
# [309/3800] 📥 Fetching goals for fixture 192611
# [310/3800] 📥 Fetching goals for fixture 192613
# [311/3800] 📥 Fetching goals for fixture 192614
# [312/3800] 📥 Fetching goals for fixture 192615
# [313/3800] 📥 Fetching goals for fixture 192616
# [314/3800] 📥 Fetching goals for fixture 192617
# [315/3800] 📥 Fetching goals for fixture 192620
# [316/3800] 📥 Fetching goals for fixture 192621
# [317/3800] 📥 Fetching goals for fixture 192622
# [318/3800] 📥 Fetching goals for fixture 192618
# [319/3800] 📥 Fetching goals for fixture 192619
# [320/3800] 📥 Fetching goals for fixture 192623
# [321/3800] 📥 Fetching goals for fixture 192624
# [322/3800] 📥 Fetching goals for fixture 192625
# [323/3800] 📥 Fetching goals for fixture 192626
# [324/3800] 📥 Fetching goals for fixture 192637
# [325/3800] 📥 Fetching goals for fixture 192627
# [326/3800] 📥 Fetching goals for fixture 192628
# [327/3800] 📥 Fetching goals for fixture 192630
# [328/3800] 📥 Fetching goals for fixture 192629
# [329/3800] 📥 Fetching goals for fixture 192631
# [330/3800] 📥 Fetching goals for fixture 192632
# [331/3800] 📥 Fetching goals for fixture 192633
# [332/3800] 📥 Fetching goals for fixture 192634
# [333/3800] 📥 Fetching goals for fixture 192635
# [334/3800] 📥 Fetching goals for fixture 192636
# [335/3800] 📥 Fetching goals for fixture 192565
# [336/3800] 📥 Fetching goals for fixture 192592
# [337/3800] 📥 Fetching goals for fixture 192593
# [338/3800] 📥 Fetching goals for fixture 192566
# [339/3800] 📥 Fetching goals for fixture 192594
# [340/3800] 📥 Fetching goals for fixture 192638
# [341/3800] 📥 Fetching goals for fixture 192639
# [342/3800] 📥 Fetching goals for fixture 192640
# [343/3800] 📥 Fetching goals for fixture 192641
# [344/3800] 📥 Fetching goals for fixture 192642
# [345/3800] 📥 Fetching goals for fixture 192643
# [346/3800] 📥 Fetching goals for fixture 192644
# [347/3800] 📥 Fetching goals for fixture 192649
# [348/3800] 📥 Fetching goals for fixture 192647
# [349/3800] 📥 Fetching goals for fixture 192648
# [350/3800] 📥 Fetching goals for fixture 192651
# [351/3800] 📥 Fetching goals for fixture 192650
# [352/3800] 📥 Fetching goals for fixture 192652
# [353/3800] 📥 Fetching goals for fixture 192653
# [354/3800] 📥 Fetching goals for fixture 192654
# [355/3800] 📥 Fetching goals for fixture 192655
# [356/3800] 📥 Fetching goals for fixture 192656
# [357/3800] 📥 Fetching goals for fixture 192657
# [358/3800] 📥 Fetching goals for fixture 192662
# [359/3800] 📥 Fetching goals for fixture 192661
# [360/3800] 📥 Fetching goals for fixture 192660
# [361/3800] 📥 Fetching goals for fixture 192659
# [362/3800] 📥 Fetching goals for fixture 192658
# [363/3800] 📥 Fetching goals for fixture 192663
# [364/3800] 📥 Fetching goals for fixture 192664
# [365/3800] 📥 Fetching goals for fixture 192666
# [366/3800] 📥 Fetching goals for fixture 192665
# [367/3800] 📥 Fetching goals for fixture 192645
# [368/3800] 📥 Fetching goals for fixture 192646
# [369/3800] 📥 Fetching goals for fixture 192595
# [370/3800] 📥 Fetching goals for fixture 192596
# [371/3800] 📥 Fetching goals for fixture 192674
# [372/3800] 📥 Fetching goals for fixture 192673
# [373/3800] 📥 Fetching goals for fixture 192668
# [374/3800] 📥 Fetching goals for fixture 192667
# [375/3800] 📥 Fetching goals for fixture 192672
# [376/3800] 📥 Fetching goals for fixture 192669
# [377/3800] 📥 Fetching goals for fixture 192670
# [378/3800] 📥 Fetching goals for fixture 192675
# [379/3800] 📥 Fetching goals for fixture 192671
# [380/3800] 📥 Fetching goals for fixture 192676
# [381/3800] 📥 Fetching goals for fixture 17696
# [382/3800] 📥 Fetching goals for fixture 17695
# [383/3800] 📥 Fetching goals for fixture 17691
# [384/3800] 📥 Fetching goals for fixture 17693
# [385/3800] 📥 Fetching goals for fixture 17692
# [386/3800] 📥 Fetching goals for fixture 17694
# [387/3800] 📥 Fetching goals for fixture 17690
# [388/3800] 📥 Fetching goals for fixture 17689
# [389/3800] 📥 Fetching goals for fixture 17688
# [390/3800] 📥 Fetching goals for fixture 17687
# [391/3800] 📥 Fetching goals for fixture 17686
# [392/3800] 📥 Fetching goals for fixture 17685
# [393/3800] 📥 Fetching goals for fixture 17683
# [394/3800] 📥 Fetching goals for fixture 17680
# [395/3800] 📥 Fetching goals for fixture 17682
# [396/3800] 📥 Fetching goals for fixture 17684
# [397/3800] 📥 Fetching goals for fixture 17681
# [398/3800] 📥 Fetching goals for fixture 17679
# [399/3800] 📥 Fetching goals for fixture 17678
# [400/3800] 📥 Fetching goals for fixture 17677
# [401/3800] 📥 Fetching goals for fixture 17676
# [402/3800] 📥 Fetching goals for fixture 17675
# [403/3800] 📥 Fetching goals for fixture 17674
# [404/3800] 📥 Fetching goals for fixture 17672
# [405/3800] 📥 Fetching goals for fixture 17673
# [406/3800] 📥 Fetching goals for fixture 17670
# [407/3800] 📥 Fetching goals for fixture 17671
# [408/3800] 📥 Fetching goals for fixture 17669
# [409/3800] 📥 Fetching goals for fixture 17668
# [410/3800] 📥 Fetching goals for fixture 17667
# [411/3800] 📥 Fetching goals for fixture 17666
# [412/3800] 📥 Fetching goals for fixture 17661
# [413/3800] 📥 Fetching goals for fixture 17660
# [414/3800] 📥 Fetching goals for fixture 17662
# [415/3800] 📥 Fetching goals for fixture 17665
# [416/3800] 📥 Fetching goals for fixture 17663
# [417/3800] 📥 Fetching goals for fixture 17664
# [418/3800] 📥 Fetching goals for fixture 17659
# [419/3800] 📥 Fetching goals for fixture 17658
# [420/3800] 📥 Fetching goals for fixture 17657
# [421/3800] 📥 Fetching goals for fixture 17656
# [422/3800] 📥 Fetching goals for fixture 17653
# [423/3800] 📥 Fetching goals for fixture 17654
# [424/3800] 📥 Fetching goals for fixture 17655
# [425/3800] 📥 Fetching goals for fixture 17652
# [426/3800] 📥 Fetching goals for fixture 17651
# [427/3800] 📥 Fetching goals for fixture 17650
# [428/3800] 📥 Fetching goals for fixture 17649
# [429/3800] 📥 Fetching goals for fixture 17648
# [430/3800] 📥 Fetching goals for fixture 17647
# [431/3800] 📥 Fetching goals for fixture 17646
# [432/3800] 📥 Fetching goals for fixture 17640
# [433/3800] 📥 Fetching goals for fixture 17641
# [434/3800] 📥 Fetching goals for fixture 17642
# [435/3800] 📥 Fetching goals for fixture 17643
# [436/3800] 📥 Fetching goals for fixture 17645
# [437/3800] 📥 Fetching goals for fixture 17644
# [438/3800] 📥 Fetching goals for fixture 17639
# [439/3800] 📥 Fetching goals for fixture 17638
# [440/3800] 📥 Fetching goals for fixture 17637
# [441/3800] 📥 Fetching goals for fixture 17636
# [442/3800] 📥 Fetching goals for fixture 17635
# [443/3800] 📥 Fetching goals for fixture 17633
# [444/3800] 📥 Fetching goals for fixture 17634
# [445/3800] 📥 Fetching goals for fixture 17631
# [446/3800] 📥 Fetching goals for fixture 17632
# [447/3800] 📥 Fetching goals for fixture 17630
# [448/3800] 📥 Fetching goals for fixture 17628
# [449/3800] 📥 Fetching goals for fixture 17629
# [450/3800] 📥 Fetching goals for fixture 17627
# [451/3800] 📥 Fetching goals for fixture 17626
# [452/3800] 📥 Fetching goals for fixture 17622
# [453/3800] 📥 Fetching goals for fixture 17621
# [454/3800] 📥 Fetching goals for fixture 17623
# [455/3800] 📥 Fetching goals for fixture 17625
# [456/3800] 📥 Fetching goals for fixture 17624
# [457/3800] 📥 Fetching goals for fixture 17620
# [458/3800] 📥 Fetching goals for fixture 17619
# [459/3800] 📥 Fetching goals for fixture 17618
# [460/3800] 📥 Fetching goals for fixture 17617
# [461/3800] 📥 Fetching goals for fixture 17616
# [462/3800] 📥 Fetching goals for fixture 17610
# [463/3800] 📥 Fetching goals for fixture 17611
# [464/3800] 📥 Fetching goals for fixture 17613
# [465/3800] 📥 Fetching goals for fixture 17615
# [466/3800] 📥 Fetching goals for fixture 17612
# [467/3800] 📥 Fetching goals for fixture 17614
# [468/3800] 📥 Fetching goals for fixture 17609
# [469/3800] 📥 Fetching goals for fixture 17608
# [470/3800] 📥 Fetching goals for fixture 17607
# [471/3800] 📥 Fetching goals for fixture 17606
# [472/3800] 📥 Fetching goals for fixture 17601
# [473/3800] 📥 Fetching goals for fixture 17604
# [474/3800] 📥 Fetching goals for fixture 17603
# [475/3800] 📥 Fetching goals for fixture 17605
# [476/3800] 📥 Fetching goals for fixture 17602
# [477/3800] 📥 Fetching goals for fixture 17600
# [478/3800] 📥 Fetching goals for fixture 17599
# [479/3800] 📥 Fetching goals for fixture 17598
# [480/3800] 📥 Fetching goals for fixture 17597
# [481/3800] 📥 Fetching goals for fixture 17593
# [482/3800] 📥 Fetching goals for fixture 17594
# [483/3800] 📥 Fetching goals for fixture 17596
# [484/3800] 📥 Fetching goals for fixture 17595
# [485/3800] 📥 Fetching goals for fixture 17592
# [486/3800] 📥 Fetching goals for fixture 17591
# [487/3800] 📥 Fetching goals for fixture 17590
# [488/3800] 📥 Fetching goals for fixture 17589
# [489/3800] 📥 Fetching goals for fixture 17588
# [490/3800] 📥 Fetching goals for fixture 17587
# [491/3800] 📥 Fetching goals for fixture 17586
# [492/3800] 📥 Fetching goals for fixture 17585
# [493/3800] 📥 Fetching goals for fixture 17582
# [494/3800] 📥 Fetching goals for fixture 17581
# [495/3800] 📥 Fetching goals for fixture 17580
# [496/3800] 📥 Fetching goals for fixture 17583
# [497/3800] 📥 Fetching goals for fixture 17584
# [498/3800] 📥 Fetching goals for fixture 17579
# [499/3800] 📥 Fetching goals for fixture 17578
# [500/3800] 📥 Fetching goals for fixture 17577
# [501/3800] 📥 Fetching goals for fixture 17576
# [502/3800] 📥 Fetching goals for fixture 17574
# [503/3800] 📥 Fetching goals for fixture 17573
# [504/3800] 📥 Fetching goals for fixture 17572
# [505/3800] 📥 Fetching goals for fixture 17575
# [506/3800] 📥 Fetching goals for fixture 17571
# [507/3800] 📥 Fetching goals for fixture 17570
# [508/3800] 📥 Fetching goals for fixture 17569
# [509/3800] 📥 Fetching goals for fixture 17567
# [510/3800] 📥 Fetching goals for fixture 17568
# [511/3800] 📥 Fetching goals for fixture 17566
# [512/3800] 📥 Fetching goals for fixture 17564
# [513/3800] 📥 Fetching goals for fixture 17561
# [514/3800] 📥 Fetching goals for fixture 17565
# [515/3800] 📥 Fetching goals for fixture 17562
# [516/3800] 📥 Fetching goals for fixture 17563
# [517/3800] 📥 Fetching goals for fixture 17560
# [518/3800] 📥 Fetching goals for fixture 17559
# [519/3800] 📥 Fetching goals for fixture 17558
# [520/3800] 📥 Fetching goals for fixture 17557
# [521/3800] 📥 Fetching goals for fixture 17556
# [522/3800] 📥 Fetching goals for fixture 17552
# [523/3800] 📥 Fetching goals for fixture 17553
# [524/3800] 📥 Fetching goals for fixture 17554
# [525/3800] 📥 Fetching goals for fixture 17555
# [526/3800] 📥 Fetching goals for fixture 17551
# [527/3800] 📥 Fetching goals for fixture 17550
# [528/3800] 📥 Fetching goals for fixture 17548
# [529/3800] 📥 Fetching goals for fixture 17549
# [530/3800] 📥 Fetching goals for fixture 17547
# [531/3800] 📥 Fetching goals for fixture 17545
# [532/3800] 📥 Fetching goals for fixture 17546
# [533/3800] 📥 Fetching goals for fixture 17544
# [534/3800] 📥 Fetching goals for fixture 17542
# [535/3800] 📥 Fetching goals for fixture 17543
# [536/3800] 📥 Fetching goals for fixture 17540
# [537/3800] 📥 Fetching goals for fixture 17538
# [538/3800] 📥 Fetching goals for fixture 17537
# [539/3800] 📥 Fetching goals for fixture 17541
# [540/3800] 📥 Fetching goals for fixture 17539
# [541/3800] 📥 Fetching goals for fixture 17536
# [542/3800] 📥 Fetching goals for fixture 17535
# [543/3800] 📥 Fetching goals for fixture 17532
# [544/3800] 📥 Fetching goals for fixture 17533
# [545/3800] 📥 Fetching goals for fixture 17534
# [546/3800] 📥 Fetching goals for fixture 17531
# [547/3800] 📥 Fetching goals for fixture 17530
# [548/3800] 📥 Fetching goals for fixture 17529
# [549/3800] 📥 Fetching goals for fixture 17528
# [550/3800] 📥 Fetching goals for fixture 17527
# [551/3800] 📥 Fetching goals for fixture 17526
# [552/3800] 📥 Fetching goals for fixture 17524
# [553/3800] 📥 Fetching goals for fixture 17520
# [554/3800] 📥 Fetching goals for fixture 17521
# [555/3800] 📥 Fetching goals for fixture 17523
# [556/3800] 📥 Fetching goals for fixture 17522
# [557/3800] 📥 Fetching goals for fixture 17525
# [558/3800] 📥 Fetching goals for fixture 17519
# [559/3800] 📥 Fetching goals for fixture 17518
# [560/3800] 📥 Fetching goals for fixture 17517
# [561/3800] 📥 Fetching goals for fixture 17516
# [562/3800] 📥 Fetching goals for fixture 17513
# [563/3800] 📥 Fetching goals for fixture 17514
# [564/3800] 📥 Fetching goals for fixture 17510
# [565/3800] 📥 Fetching goals for fixture 17512
# [566/3800] 📥 Fetching goals for fixture 17511
# [567/3800] 📥 Fetching goals for fixture 17515
# [568/3800] 📥 Fetching goals for fixture 17509
# [569/3800] 📥 Fetching goals for fixture 17508
# [570/3800] 📥 Fetching goals for fixture 17507
# [571/3800] 📥 Fetching goals for fixture 17506
# [572/3800] 📥 Fetching goals for fixture 17502
# [573/3800] 📥 Fetching goals for fixture 17503
# [574/3800] 📥 Fetching goals for fixture 17505
# [575/3800] 📥 Fetching goals for fixture 17504
# [576/3800] 📥 Fetching goals for fixture 17501
# [577/3800] 📥 Fetching goals for fixture 17500
# [578/3800] 📥 Fetching goals for fixture 17498
# [579/3800] 📥 Fetching goals for fixture 17499
# [580/3800] 📥 Fetching goals for fixture 17497
# [581/3800] 📥 Fetching goals for fixture 17496
# [582/3800] 📥 Fetching goals for fixture 17494
# [583/3800] 📥 Fetching goals for fixture 17490
# [584/3800] 📥 Fetching goals for fixture 17495
# [585/3800] 📥 Fetching goals for fixture 17491
# [586/3800] 📥 Fetching goals for fixture 17493
# [587/3800] 📥 Fetching goals for fixture 17492
# [588/3800] 📥 Fetching goals for fixture 17489
# [589/3800] 📥 Fetching goals for fixture 17488
# [590/3800] 📥 Fetching goals for fixture 17487
# [591/3800] 📥 Fetching goals for fixture 17486
# [592/3800] 📥 Fetching goals for fixture 17481
# [593/3800] 📥 Fetching goals for fixture 17482
# [594/3800] 📥 Fetching goals for fixture 17485
# [595/3800] 📥 Fetching goals for fixture 17483
# [596/3800] 📥 Fetching goals for fixture 17484
# [597/3800] 📥 Fetching goals for fixture 17480
# [598/3800] 📥 Fetching goals for fixture 17479
# [599/3800] 📥 Fetching goals for fixture 17478
# [600/3800] 📥 Fetching goals for fixture 17477
# [601/3800] 📥 Fetching goals for fixture 17472
# [602/3800] 📥 Fetching goals for fixture 17471
# [603/3800] 📥 Fetching goals for fixture 17473
# [604/3800] 📥 Fetching goals for fixture 17474
# [605/3800] 📥 Fetching goals for fixture 17476
# [606/3800] 📥 Fetching goals for fixture 17475
# [607/3800] 📥 Fetching goals for fixture 17470
# [608/3800] 📥 Fetching goals for fixture 17469
# [609/3800] 📥 Fetching goals for fixture 17467
# [610/3800] 📥 Fetching goals for fixture 17468
# [611/3800] 📥 Fetching goals for fixture 17466
# [612/3800] 📥 Fetching goals for fixture 17464
# [613/3800] 📥 Fetching goals for fixture 17463
# [614/3800] 📥 Fetching goals for fixture 17461
# [615/3800] 📥 Fetching goals for fixture 17460
# [616/3800] 📥 Fetching goals for fixture 17465
# [617/3800] 📥 Fetching goals for fixture 17462
# [618/3800] 📥 Fetching goals for fixture 17459
# [619/3800] 📥 Fetching goals for fixture 17458
# [620/3800] 📥 Fetching goals for fixture 17457
# [621/3800] 📥 Fetching goals for fixture 17456
# [622/3800] 📥 Fetching goals for fixture 17451
# [623/3800] 📥 Fetching goals for fixture 17455
# [624/3800] 📥 Fetching goals for fixture 17452
# [625/3800] 📥 Fetching goals for fixture 17453
# [626/3800] 📥 Fetching goals for fixture 17454
# [627/3800] 📥 Fetching goals for fixture 17450
# [628/3800] 📥 Fetching goals for fixture 17449
# [629/3800] 📥 Fetching goals for fixture 17448
# [630/3800] 📥 Fetching goals for fixture 17447
# [631/3800] 📥 Fetching goals for fixture 17444
# [632/3800] 📥 Fetching goals for fixture 17442
# [633/3800] 📥 Fetching goals for fixture 17443
# [634/3800] 📥 Fetching goals for fixture 17446
# [635/3800] 📥 Fetching goals for fixture 17445
# [636/3800] 📥 Fetching goals for fixture 17441
# [637/3800] 📥 Fetching goals for fixture 17440
# [638/3800] 📥 Fetching goals for fixture 17439
# [639/3800] 📥 Fetching goals for fixture 17438
# [640/3800] 📥 Fetching goals for fixture 17436
# [641/3800] 📥 Fetching goals for fixture 17433
# [642/3800] 📥 Fetching goals for fixture 17437
# [643/3800] 📥 Fetching goals for fixture 17434
# [644/3800] 📥 Fetching goals for fixture 17435
# [645/3800] 📥 Fetching goals for fixture 17432
# [646/3800] 📥 Fetching goals for fixture 17431
# [647/3800] 📥 Fetching goals for fixture 17430
# [648/3800] 📥 Fetching goals for fixture 17429
# [649/3800] 📥 Fetching goals for fixture 17428
# [650/3800] 📥 Fetching goals for fixture 17425
# [651/3800] 📥 Fetching goals for fixture 17426
# [652/3800] 📥 Fetching goals for fixture 17427
# [653/3800] 📥 Fetching goals for fixture 17424
# [654/3800] 📥 Fetching goals for fixture 17423
# [655/3800] 📥 Fetching goals for fixture 17419
# [656/3800] 📥 Fetching goals for fixture 17422
# [657/3800] 📥 Fetching goals for fixture 17418
# [658/3800] 📥 Fetching goals for fixture 17420
# [659/3800] 📥 Fetching goals for fixture 17421
# [660/3800] 📥 Fetching goals for fixture 17417
# [661/3800] 📥 Fetching goals for fixture 17416
# [662/3800] 📥 Fetching goals for fixture 17415
# [663/3800] 📥 Fetching goals for fixture 17414
# [664/3800] 📥 Fetching goals for fixture 17413
# [665/3800] 📥 Fetching goals for fixture 17411
# [666/3800] 📥 Fetching goals for fixture 17412
# [667/3800] 📥 Fetching goals for fixture 17407
# [668/3800] 📥 Fetching goals for fixture 17410
# [669/3800] 📥 Fetching goals for fixture 17408
# [670/3800] 📥 Fetching goals for fixture 17409
# [671/3800] 📥 Fetching goals for fixture 17406
# [672/3800] 📥 Fetching goals for fixture 17405
# [673/3800] 📥 Fetching goals for fixture 17404
# [674/3800] 📥 Fetching goals for fixture 17403
# [675/3800] 📥 Fetching goals for fixture 17401
# [676/3800] 📥 Fetching goals for fixture 17402
# [677/3800] 📥 Fetching goals for fixture 17400
# [678/3800] 📥 Fetching goals for fixture 17398
# [679/3800] 📥 Fetching goals for fixture 17396
# [680/3800] 📥 Fetching goals for fixture 17397
# [681/3800] 📥 Fetching goals for fixture 17399
# [682/3800] 📥 Fetching goals for fixture 17395
# [683/3800] 📥 Fetching goals for fixture 17394
# [684/3800] 📥 Fetching goals for fixture 17393
# [685/3800] 📥 Fetching goals for fixture 17392
# [686/3800] 📥 Fetching goals for fixture 17388
# [687/3800] 📥 Fetching goals for fixture 17391
# [688/3800] 📥 Fetching goals for fixture 17389
# [689/3800] 📥 Fetching goals for fixture 17390
# [690/3800] 📥 Fetching goals for fixture 17387
# [691/3800] 📥 Fetching goals for fixture 17386
# [692/3800] 📥 Fetching goals for fixture 17385
# [693/3800] 📥 Fetching goals for fixture 17384
# [694/3800] 📥 Fetching goals for fixture 17383
# [695/3800] 📥 Fetching goals for fixture 17382
# [696/3800] 📥 Fetching goals for fixture 17379
# [697/3800] 📥 Fetching goals for fixture 17378
# [698/3800] 📥 Fetching goals for fixture 17380
# [699/3800] 📥 Fetching goals for fixture 17381
# [700/3800] 📥 Fetching goals for fixture 17377
# [701/3800] 📥 Fetching goals for fixture 17376
# [702/3800] 📥 Fetching goals for fixture 17375
# [703/3800] 📥 Fetching goals for fixture 17374
# [704/3800] 📥 Fetching goals for fixture 17370
# [705/3800] 📥 Fetching goals for fixture 17373
# [706/3800] 📥 Fetching goals for fixture 17371
# [707/3800] 📥 Fetching goals for fixture 17372
# [708/3800] 📥 Fetching goals for fixture 17369
# [709/3800] 📥 Fetching goals for fixture 17368
# [710/3800] 📥 Fetching goals for fixture 17367
# [711/3800] 📥 Fetching goals for fixture 17365
# [712/3800] 📥 Fetching goals for fixture 17366
# [713/3800] 📥 Fetching goals for fixture 17364
# [714/3800] 📥 Fetching goals for fixture 17363
# [715/3800] 📥 Fetching goals for fixture 17359
# [716/3800] 📥 Fetching goals for fixture 17362
# [717/3800] 📥 Fetching goals for fixture 17360
# [718/3800] 📥 Fetching goals for fixture 17361
# [719/3800] 📥 Fetching goals for fixture 17358
# [720/3800] 📥 Fetching goals for fixture 17357
# [721/3800] 📥 Fetching goals for fixture 17355
# [722/3800] 📥 Fetching goals for fixture 17356
# [723/3800] 📥 Fetching goals for fixture 17354
# [724/3800] 📥 Fetching goals for fixture 17353
# [725/3800] 📥 Fetching goals for fixture 17352
# [726/3800] 📥 Fetching goals for fixture 17351
# [727/3800] 📥 Fetching goals for fixture 17347
# [728/3800] 📥 Fetching goals for fixture 17348
# [729/3800] 📥 Fetching goals for fixture 17350
# [730/3800] 📥 Fetching goals for fixture 17349
# [731/3800] 📥 Fetching goals for fixture 17346
# [732/3800] 📥 Fetching goals for fixture 17345
# [733/3800] 📥 Fetching goals for fixture 17344
# [734/3800] 📥 Fetching goals for fixture 17343
# [735/3800] 📥 Fetching goals for fixture 17342
# [736/3800] 📥 Fetching goals for fixture 17341
# [737/3800] 📥 Fetching goals for fixture 17340
# [738/3800] 📥 Fetching goals for fixture 17339
# [739/3800] 📥 Fetching goals for fixture 17336
# [740/3800] 📥 Fetching goals for fixture 17337
# [741/3800] 📥 Fetching goals for fixture 17338
# [742/3800] 📥 Fetching goals for fixture 17335
# [743/3800] 📥 Fetching goals for fixture 17334
# [744/3800] 📥 Fetching goals for fixture 17333
# [745/3800] 📥 Fetching goals for fixture 17332
# [746/3800] 📥 Fetching goals for fixture 17331
# [747/3800] 📥 Fetching goals for fixture 17330
# [748/3800] 📥 Fetching goals for fixture 17329
# [749/3800] 📥 Fetching goals for fixture 17328
# [750/3800] 📥 Fetching goals for fixture 17327
# [751/3800] 📥 Fetching goals for fixture 17323
# [752/3800] 📥 Fetching goals for fixture 17326
# [753/3800] 📥 Fetching goals for fixture 17322
# [754/3800] 📥 Fetching goals for fixture 17324
# [755/3800] 📥 Fetching goals for fixture 17317
# [756/3800] 📥 Fetching goals for fixture 17318
# [757/3800] 📥 Fetching goals for fixture 17321
# [758/3800] 📥 Fetching goals for fixture 17319
# [759/3800] 📥 Fetching goals for fixture 17320
# [760/3800] 📥 Fetching goals for fixture 17325
# [761/3800] 📥 Fetching goals for fixture 11911
# [762/3800] 📥 Fetching goals for fixture 11910
# [763/3800] 📥 Fetching goals for fixture 11908
# [764/3800] 📥 Fetching goals for fixture 11907
# [765/3800] 📥 Fetching goals for fixture 11905
# [766/3800] 📥 Fetching goals for fixture 11906
# [767/3800] 📥 Fetching goals for fixture 11909
# [768/3800] 📥 Fetching goals for fixture 11904
# [769/3800] 📥 Fetching goals for fixture 11903
# [770/3800] 📥 Fetching goals for fixture 11902
# [771/3800] 📥 Fetching goals for fixture 11901
# [772/3800] 📥 Fetching goals for fixture 11896
# [773/3800] 📥 Fetching goals for fixture 11899
# [774/3800] 📥 Fetching goals for fixture 11900
# [775/3800] 📥 Fetching goals for fixture 11897
# [776/3800] 📥 Fetching goals for fixture 11898
# [777/3800] 📥 Fetching goals for fixture 11895
# [778/3800] 📥 Fetching goals for fixture 11894
# [779/3800] 📥 Fetching goals for fixture 11893
# [780/3800] 📥 Fetching goals for fixture 11892
# [781/3800] 📥 Fetching goals for fixture 11891
# [782/3800] 📥 Fetching goals for fixture 11889
# [783/3800] 📥 Fetching goals for fixture 11888
# [784/3800] 📥 Fetching goals for fixture 11890
# [785/3800] 📥 Fetching goals for fixture 11887
# [786/3800] 📥 Fetching goals for fixture 11886
# [787/3800] 📥 Fetching goals for fixture 11884
# [788/3800] 📥 Fetching goals for fixture 11885
# [789/3800] 📥 Fetching goals for fixture 11882
# [790/3800] 📥 Fetching goals for fixture 11883
# [791/3800] 📥 Fetching goals for fixture 11881
# [792/3800] 📥 Fetching goals for fixture 11880
# [793/3800] 📥 Fetching goals for fixture 11876
# [794/3800] 📥 Fetching goals for fixture 11878
# [795/3800] 📥 Fetching goals for fixture 11879
# [796/3800] 📥 Fetching goals for fixture 11877
# [797/3800] 📥 Fetching goals for fixture 11875
# [798/3800] 📥 Fetching goals for fixture 11874
# [799/3800] 📥 Fetching goals for fixture 11873
# [800/3800] 📥 Fetching goals for fixture 11872
# [801/3800] 📥 Fetching goals for fixture 11871
# [802/3800] 📥 Fetching goals for fixture 11870
# [803/3800] 📥 Fetching goals for fixture 11867
# [804/3800] 📥 Fetching goals for fixture 11865
# [805/3800] 📥 Fetching goals for fixture 11868
# [806/3800] 📥 Fetching goals for fixture 11866
# [807/3800] 📥 Fetching goals for fixture 11869
# [808/3800] 📥 Fetching goals for fixture 11864
# [809/3800] 📥 Fetching goals for fixture 11863
# [810/3800] 📥 Fetching goals for fixture 11862
# [811/3800] 📥 Fetching goals for fixture 11861
# [812/3800] 📥 Fetching goals for fixture 11858
# [813/3800] 📥 Fetching goals for fixture 11855
# [814/3800] 📥 Fetching goals for fixture 11856
# [815/3800] 📥 Fetching goals for fixture 11857
# [816/3800] 📥 Fetching goals for fixture 11859
# [817/3800] 📥 Fetching goals for fixture 11860
# [818/3800] 📥 Fetching goals for fixture 11854
# [819/3800] 📥 Fetching goals for fixture 11853
# [820/3800] 📥 Fetching goals for fixture 11852
# [821/3800] 📥 Fetching goals for fixture 11851
# [822/3800] 📥 Fetching goals for fixture 11847
# [823/3800] 📥 Fetching goals for fixture 11846
# [824/3800] 📥 Fetching goals for fixture 11850
# [825/3800] 📥 Fetching goals for fixture 11849
# [826/3800] 📥 Fetching goals for fixture 11848
# [827/3800] 📥 Fetching goals for fixture 11845
# [828/3800] 📥 Fetching goals for fixture 11844
# [829/3800] 📥 Fetching goals for fixture 11843
# [830/3800] 📥 Fetching goals for fixture 11842
# [831/3800] 📥 Fetching goals for fixture 11841
# [832/3800] 📥 Fetching goals for fixture 11836
# [833/3800] 📥 Fetching goals for fixture 11840
# [834/3800] 📥 Fetching goals for fixture 11838
# [835/3800] 📥 Fetching goals for fixture 11837
# [836/3800] 📥 Fetching goals for fixture 11839
# [837/3800] 📥 Fetching goals for fixture 11835
# [838/3800] 📥 Fetching goals for fixture 11834
# [839/3800] 📥 Fetching goals for fixture 11833
# [840/3800] 📥 Fetching goals for fixture 11832
# [841/3800] 📥 Fetching goals for fixture 11831
# [842/3800] 📥 Fetching goals for fixture 11830
# [843/3800] 📥 Fetching goals for fixture 11827
# [844/3800] 📥 Fetching goals for fixture 11825
# [845/3800] 📥 Fetching goals for fixture 11826
# [846/3800] 📥 Fetching goals for fixture 11828
# [847/3800] 📥 Fetching goals for fixture 11829
# [848/3800] 📥 Fetching goals for fixture 11824
# [849/3800] 📥 Fetching goals for fixture 11823
# [850/3800] 📥 Fetching goals for fixture 11822
# [851/3800] 📥 Fetching goals for fixture 11821
# [852/3800] 📥 Fetching goals for fixture 11819
# [853/3800] 📥 Fetching goals for fixture 11818
# [854/3800] 📥 Fetching goals for fixture 11816
# [855/3800] 📥 Fetching goals for fixture 11817
# [856/3800] 📥 Fetching goals for fixture 11820
# [857/3800] 📥 Fetching goals for fixture 11815
# [858/3800] 📥 Fetching goals for fixture 11814
# [859/3800] 📥 Fetching goals for fixture 11813
# [860/3800] 📥 Fetching goals for fixture 11812
# [861/3800] 📥 Fetching goals for fixture 11811
# [862/3800] 📥 Fetching goals for fixture 11808
# [863/3800] 📥 Fetching goals for fixture 11807
# [864/3800] 📥 Fetching goals for fixture 11809
# [865/3800] 📥 Fetching goals for fixture 11810
# [866/3800] 📥 Fetching goals for fixture 11806
# [867/3800] 📥 Fetching goals for fixture 11805
# [868/3800] 📥 Fetching goals for fixture 11804
# [869/3800] 📥 Fetching goals for fixture 11803
# [870/3800] 📥 Fetching goals for fixture 11802
# [871/3800] 📥 Fetching goals for fixture 11801
# [872/3800] 📥 Fetching goals for fixture 11795
# [873/3800] 📥 Fetching goals for fixture 11799
# [874/3800] 📥 Fetching goals for fixture 11796
# [875/3800] 📥 Fetching goals for fixture 11798
# [876/3800] 📥 Fetching goals for fixture 11797
# [877/3800] 📥 Fetching goals for fixture 11800
# [878/3800] 📥 Fetching goals for fixture 11794
# [879/3800] 📥 Fetching goals for fixture 11793
# [880/3800] 📥 Fetching goals for fixture 11792
# [881/3800] 📥 Fetching goals for fixture 11791
# [882/3800] 📥 Fetching goals for fixture 11787
# [883/3800] 📥 Fetching goals for fixture 11788
# [884/3800] 📥 Fetching goals for fixture 11790
# [885/3800] 📥 Fetching goals for fixture 11786
# [886/3800] 📥 Fetching goals for fixture 11789
# [887/3800] 📥 Fetching goals for fixture 11785
# [888/3800] 📥 Fetching goals for fixture 11784
# [889/3800] 📥 Fetching goals for fixture 11783
# [890/3800] 📥 Fetching goals for fixture 11782
# [891/3800] 📥 Fetching goals for fixture 11781
# [892/3800] 📥 Fetching goals for fixture 11780
# [893/3800] 📥 Fetching goals for fixture 11778
# [894/3800] 📥 Fetching goals for fixture 11779
# [895/3800] 📥 Fetching goals for fixture 11776
# [896/3800] 📥 Fetching goals for fixture 11775
# [897/3800] 📥 Fetching goals for fixture 11777
# [898/3800] 📥 Fetching goals for fixture 11772
# [899/3800] 📥 Fetching goals for fixture 11773
# [900/3800] 📥 Fetching goals for fixture 11774
# [901/3800] 📥 Fetching goals for fixture 11771
# [902/3800] 📥 Fetching goals for fixture 11769
# [903/3800] 📥 Fetching goals for fixture 11766
# [904/3800] 📥 Fetching goals for fixture 11767
# [905/3800] 📥 Fetching goals for fixture 11765
# [906/3800] 📥 Fetching goals for fixture 11770
# [907/3800] 📥 Fetching goals for fixture 11768
# [908/3800] 📥 Fetching goals for fixture 11764
# [909/3800] 📥 Fetching goals for fixture 11763
# [910/3800] 📥 Fetching goals for fixture 11762
# [911/3800] 📥 Fetching goals for fixture 11761
# [912/3800] 📥 Fetching goals for fixture 11758
# [913/3800] 📥 Fetching goals for fixture 11756
# [914/3800] 📥 Fetching goals for fixture 11760
# [915/3800] 📥 Fetching goals for fixture 11757
# [916/3800] 📥 Fetching goals for fixture 11759
# [917/3800] 📥 Fetching goals for fixture 11755
# [918/3800] 📥 Fetching goals for fixture 11754
# [919/3800] 📥 Fetching goals for fixture 11753
# [920/3800] 📥 Fetching goals for fixture 11752
# [921/3800] 📥 Fetching goals for fixture 11751
# [922/3800] 📥 Fetching goals for fixture 11750
# [923/3800] 📥 Fetching goals for fixture 11749
# [924/3800] 📥 Fetching goals for fixture 11746
# [925/3800] 📥 Fetching goals for fixture 11747
# [926/3800] 📥 Fetching goals for fixture 11748
# [927/3800] 📥 Fetching goals for fixture 11743
# [928/3800] 📥 Fetching goals for fixture 11742
# [929/3800] 📥 Fetching goals for fixture 11744
# [930/3800] 📥 Fetching goals for fixture 11745
# [931/3800] 📥 Fetching goals for fixture 11741
# [932/3800] 📥 Fetching goals for fixture 11740
# [933/3800] 📥 Fetching goals for fixture 11737
# [934/3800] 📥 Fetching goals for fixture 11739
# [935/3800] 📥 Fetching goals for fixture 11738
# [936/3800] 📥 Fetching goals for fixture 11736
# [937/3800] 📥 Fetching goals for fixture 11735
# [938/3800] 📥 Fetching goals for fixture 11734
# [939/3800] 📥 Fetching goals for fixture 11733
# [940/3800] 📥 Fetching goals for fixture 11732
# [941/3800] 📥 Fetching goals for fixture 11731
# [942/3800] 📥 Fetching goals for fixture 11730
# [943/3800] 📥 Fetching goals for fixture 11726
# [944/3800] 📥 Fetching goals for fixture 11729
# [945/3800] 📥 Fetching goals for fixture 11725
# [946/3800] 📥 Fetching goals for fixture 11724
# [947/3800] 📥 Fetching goals for fixture 11727
# [948/3800] 📥 Fetching goals for fixture 11728
# [949/3800] 📥 Fetching goals for fixture 11723
# [950/3800] 📥 Fetching goals for fixture 11722
# [951/3800] 📥 Fetching goals for fixture 11721
# [952/3800] 📥 Fetching goals for fixture 11718
# [953/3800] 📥 Fetching goals for fixture 11715
# [954/3800] 📥 Fetching goals for fixture 11717
# [955/3800] 📥 Fetching goals for fixture 11719
# [956/3800] 📥 Fetching goals for fixture 11716
# [957/3800] 📥 Fetching goals for fixture 11720
# [958/3800] 📥 Fetching goals for fixture 11714
# [959/3800] 📥 Fetching goals for fixture 11713
# [960/3800] 📥 Fetching goals for fixture 11712
# [961/3800] 📥 Fetching goals for fixture 11710
# [962/3800] 📥 Fetching goals for fixture 11706
# [963/3800] 📥 Fetching goals for fixture 11708
# [964/3800] 📥 Fetching goals for fixture 11711
# [965/3800] 📥 Fetching goals for fixture 11709
# [966/3800] 📥 Fetching goals for fixture 11707
# [967/3800] 📥 Fetching goals for fixture 11705
# [968/3800] 📥 Fetching goals for fixture 11704
# [969/3800] 📥 Fetching goals for fixture 11703
# [970/3800] 📥 Fetching goals for fixture 11702
# [971/3800] 📥 Fetching goals for fixture 11699
# [972/3800] 📥 Fetching goals for fixture 11700
# [973/3800] 📥 Fetching goals for fixture 11701
# [974/3800] 📥 Fetching goals for fixture 11698
# [975/3800] 📥 Fetching goals for fixture 11695
# [976/3800] 📥 Fetching goals for fixture 11697
# [977/3800] 📥 Fetching goals for fixture 11696
# [978/3800] 📥 Fetching goals for fixture 11694
# [979/3800] 📥 Fetching goals for fixture 11693
# [980/3800] 📥 Fetching goals for fixture 11692
# [981/3800] 📥 Fetching goals for fixture 11689
# [982/3800] 📥 Fetching goals for fixture 11688
# [983/3800] 📥 Fetching goals for fixture 11690
# [984/3800] 📥 Fetching goals for fixture 11686
# [985/3800] 📥 Fetching goals for fixture 11687
# [986/3800] 📥 Fetching goals for fixture 11691
# [987/3800] 📥 Fetching goals for fixture 11685
# [988/3800] 📥 Fetching goals for fixture 11684
# [989/3800] 📥 Fetching goals for fixture 11683
# [990/3800] 📥 Fetching goals for fixture 11682
# [991/3800] 📥 Fetching goals for fixture 11681
# [992/3800] 📥 Fetching goals for fixture 11675
# [993/3800] 📥 Fetching goals for fixture 11676
# [994/3800] 📥 Fetching goals for fixture 11677
# [995/3800] 📥 Fetching goals for fixture 11678
# [996/3800] 📥 Fetching goals for fixture 11680
# [997/3800] 📥 Fetching goals for fixture 11679
# [998/3800] 📥 Fetching goals for fixture 11674
# [999/3800] 📥 Fetching goals for fixture 11673
# [1000/3800] 📥 Fetching goals for fixture 11672
# [1001/3800] 📥 Fetching goals for fixture 11671
# [1002/3800] 📥 Fetching goals for fixture 11670
# [1003/3800] 📥 Fetching goals for fixture 11669
# [1004/3800] 📥 Fetching goals for fixture 11667
# [1005/3800] 📥 Fetching goals for fixture 11668
# [1006/3800] 📥 Fetching goals for fixture 11666
# [1007/3800] 📥 Fetching goals for fixture 11665
# [1008/3800] 📥 Fetching goals for fixture 11664
# [1009/3800] 📥 Fetching goals for fixture 11662
# [1010/3800] 📥 Fetching goals for fixture 11663
# [1011/3800] 📥 Fetching goals for fixture 11661
# [1012/3800] 📥 Fetching goals for fixture 11659
# [1013/3800] 📥 Fetching goals for fixture 11656
# [1014/3800] 📥 Fetching goals for fixture 11658
# [1015/3800] 📥 Fetching goals for fixture 11657
# [1016/3800] 📥 Fetching goals for fixture 11660
# [1017/3800] 📥 Fetching goals for fixture 11655
# [1018/3800] 📥 Fetching goals for fixture 11654
# [1019/3800] 📥 Fetching goals for fixture 11653
# [1020/3800] 📥 Fetching goals for fixture 11652
# [1021/3800] 📥 Fetching goals for fixture 11651
# [1022/3800] 📥 Fetching goals for fixture 11647
# [1023/3800] 📥 Fetching goals for fixture 11650
# [1024/3800] 📥 Fetching goals for fixture 11648
# [1025/3800] 📥 Fetching goals for fixture 11649
# [1026/3800] 📥 Fetching goals for fixture 11646
# [1027/3800] 📥 Fetching goals for fixture 11645
# [1028/3800] 📥 Fetching goals for fixture 11644
# [1029/3800] 📥 Fetching goals for fixture 11643
# [1030/3800] 📥 Fetching goals for fixture 11642
# [1031/3800] 📥 Fetching goals for fixture 11641
# [1032/3800] 📥 Fetching goals for fixture 11636
# [1033/3800] 📥 Fetching goals for fixture 11639
# ...
# [3489/3800] 📥 Fetching goals for fixture 1208082
# [3490/3800] 📥 Fetching goals for fixture 1208084
# [3491/3800] 📥 Fetching goals for fixture 1208099
# [3492/3800] 📥 Fetching goals for fixture 1208095
# [3493/3800] 📥 Fetching goals for fixture 1208096
# [3494/3800] 📥 Fetching goals for fixture 1208092
# [3495/3800] 📥 Fetching goals for fixture 1208098
# [3496/3800] 📥 Fetching goals for fixture 1208093
# [3497/3800] 📥 Fetching goals for fixture 1208091
# [3498/3800] 📥 Fetching goals for fixture 1208100
# [3499/3800] 📥 Fetching goals for fixture 1208094
# [3500/3800] 📥 Fetching goals for fixture 1208097
# [3501/3800] 📥 Fetching goals for fixture 1208110
# [3502/3800] 📥 Fetching goals for fixture 1208111
# [3503/3800] 📥 Fetching goals for fixture 1208106
# [3504/3800] 📥 Fetching goals for fixture 1208105
# [3505/3800] 📥 Fetching goals for fixture 1208104
# [3506/3800] 📥 Fetching goals for fixture 1208109
# [3507/3800] 📥 Fetching goals for fixture 1208112
# [3508/3800] 📥 Fetching goals for fixture 1208107
# [3509/3800] 📥 Fetching goals for fixture 1208108
# [3510/3800] 📥 Fetching goals for fixture 1208103
# [3511/3800] 📥 Fetching goals for fixture 1208118
# [3512/3800] 📥 Fetching goals for fixture 1208113
# [3513/3800] 📥 Fetching goals for fixture 1208116
# [3514/3800] 📥 Fetching goals for fixture 1208120
# [3515/3800] 📥 Fetching goals for fixture 1208115
# [3516/3800] 📥 Fetching goals for fixture 1208119
# [3517/3800] 📥 Fetching goals for fixture 1208122
# [3518/3800] 📥 Fetching goals for fixture 1208121
# [3519/3800] 📥 Fetching goals for fixture 1208117
# [3520/3800] 📥 Fetching goals for fixture 1208114
# [3521/3800] 📥 Fetching goals for fixture 1208132
# [3522/3800] 📥 Fetching goals for fixture 1208131
# [3523/3800] 📥 Fetching goals for fixture 1208126
# [3524/3800] 📥 Fetching goals for fixture 1208123
# [3525/3800] 📥 Fetching goals for fixture 1208124
# [3526/3800] 📥 Fetching goals for fixture 1208127
# [3527/3800] 📥 Fetching goals for fixture 1208128
# [3528/3800] 📥 Fetching goals for fixture 1208130
# [3529/3800] 📥 Fetching goals for fixture 1208129
# [3530/3800] 📥 Fetching goals for fixture 1208125
# [3531/3800] 📥 Fetching goals for fixture 1208139
# [3532/3800] 📥 Fetching goals for fixture 1208133
# [3533/3800] 📥 Fetching goals for fixture 1208137
# [3534/3800] 📥 Fetching goals for fixture 1208134
# [3535/3800] 📥 Fetching goals for fixture 1208136
# [3536/3800] 📥 Fetching goals for fixture 1208135
# [3537/3800] 📥 Fetching goals for fixture 1208140
# [3538/3800] 📥 Fetching goals for fixture 1208142
# [3539/3800] 📥 Fetching goals for fixture 1208138
# [3540/3800] 📥 Fetching goals for fixture 1208141
# [3541/3800] 📥 Fetching goals for fixture 1208144
# [3542/3800] 📥 Fetching goals for fixture 1208152
# [3543/3800] 📥 Fetching goals for fixture 1208146
# [3544/3800] 📥 Fetching goals for fixture 1208143
# [3545/3800] 📥 Fetching goals for fixture 1208149
# [3546/3800] 📥 Fetching goals for fixture 1208151
# [3547/3800] 📥 Fetching goals for fixture 1208148
# [3548/3800] 📥 Fetching goals for fixture 1208150
# [3549/3800] 📥 Fetching goals for fixture 1208145
# [3550/3800] 📥 Fetching goals for fixture 1208147
# [3551/3800] 📥 Fetching goals for fixture 1208158
# [3552/3800] 📥 Fetching goals for fixture 1208159
# [3553/3800] 📥 Fetching goals for fixture 1208161
# [3554/3800] 📥 Fetching goals for fixture 1208162
# [3555/3800] 📥 Fetching goals for fixture 1208156
# [3556/3800] 📥 Fetching goals for fixture 1208160
# [3557/3800] 📥 Fetching goals for fixture 1208154
# [3558/3800] 📥 Fetching goals for fixture 1208155
# [3559/3800] 📥 Fetching goals for fixture 1208157
# [3560/3800] 📥 Fetching goals for fixture 1208153
# [3561/3800] 📥 Fetching goals for fixture 1208165
# [3562/3800] 📥 Fetching goals for fixture 1208164
# [3563/3800] 📥 Fetching goals for fixture 1208163
# [3564/3800] 📥 Fetching goals for fixture 1208170
# [3565/3800] 📥 Fetching goals for fixture 1208167
# [3566/3800] 📥 Fetching goals for fixture 1208169
# [3567/3800] 📥 Fetching goals for fixture 1208168
# [3568/3800] 📥 Fetching goals for fixture 1208171
# [3569/3800] 📥 Fetching goals for fixture 1208172
# [3570/3800] 📥 Fetching goals for fixture 1208179
# [3571/3800] 📥 Fetching goals for fixture 1208182
# [3572/3800] 📥 Fetching goals for fixture 1208177
# [3573/3800] 📥 Fetching goals for fixture 1208174
# [3574/3800] 📥 Fetching goals for fixture 1208180
# [3575/3800] 📥 Fetching goals for fixture 1208175
# [3576/3800] 📥 Fetching goals for fixture 1208178
# [3577/3800] 📥 Fetching goals for fixture 1208181
# [3578/3800] 📥 Fetching goals for fixture 1208176
# [3579/3800] 📥 Fetching goals for fixture 1208173
# [3580/3800] 📥 Fetching goals for fixture 1208183
# [3581/3800] 📥 Fetching goals for fixture 1208192
# [3582/3800] 📥 Fetching goals for fixture 1208184
# [3583/3800] 📥 Fetching goals for fixture 1208188
# [3584/3800] 📥 Fetching goals for fixture 1208185
# [3585/3800] 📥 Fetching goals for fixture 1208190
# [3586/3800] 📥 Fetching goals for fixture 1208187
# [3587/3800] 📥 Fetching goals for fixture 1208186
# [3588/3800] 📥 Fetching goals for fixture 1208189
# [3589/3800] 📥 Fetching goals for fixture 1208191
# [3590/3800] 📥 Fetching goals for fixture 1208198
# [3591/3800] 📥 Fetching goals for fixture 1208199
# [3592/3800] 📥 Fetching goals for fixture 1208193
# [3593/3800] 📥 Fetching goals for fixture 1208201
# [3594/3800] 📥 Fetching goals for fixture 1208196
# [3595/3800] 📥 Fetching goals for fixture 1208200
# [3596/3800] 📥 Fetching goals for fixture 1208202
# [3597/3800] 📥 Fetching goals for fixture 1208197
# [3598/3800] 📥 Fetching goals for fixture 1208195
# [3599/3800] 📥 Fetching goals for fixture 1208194
# [3600/3800] 📥 Fetching goals for fixture 1208209
# [3601/3800] 📥 Fetching goals for fixture 1208207
# [3602/3800] 📥 Fetching goals for fixture 1208206
# [3603/3800] 📥 Fetching goals for fixture 1208211
# [3604/3800] 📥 Fetching goals for fixture 1208205
# [3605/3800] 📥 Fetching goals for fixture 1208212
# [3606/3800] 📥 Fetching goals for fixture 1208208
# [3607/3800] 📥 Fetching goals for fixture 1208203
# [3608/3800] 📥 Fetching goals for fixture 1208210
# [3609/3800] 📥 Fetching goals for fixture 1208204
# [3610/3800] 📥 Fetching goals for fixture 1208221
# [3611/3800] 📥 Fetching goals for fixture 1208213
# [3612/3800] 📥 Fetching goals for fixture 1208220
# [3613/3800] 📥 Fetching goals for fixture 1208219
# [3614/3800] 📥 Fetching goals for fixture 1208216
# [3615/3800] 📥 Fetching goals for fixture 1208214
# [3616/3800] 📥 Fetching goals for fixture 1208215
# [3617/3800] 📥 Fetching goals for fixture 1208217
# [3618/3800] 📥 Fetching goals for fixture 1208218
# [3619/3800] 📥 Fetching goals for fixture 1208222
# [3620/3800] 📥 Fetching goals for fixture 1208229
# [3621/3800] 📥 Fetching goals for fixture 1208230
# [3622/3800] 📥 Fetching goals for fixture 1208224
# [3623/3800] 📥 Fetching goals for fixture 1208228
# [3624/3800] 📥 Fetching goals for fixture 1208231
# [3625/3800] 📥 Fetching goals for fixture 1208225
# [3626/3800] 📥 Fetching goals for fixture 1208227
# [3627/3800] 📥 Fetching goals for fixture 1208223
# [3628/3800] 📥 Fetching goals for fixture 1208226
# [3629/3800] 📥 Fetching goals for fixture 1208232
# [3630/3800] 📥 Fetching goals for fixture 1208240
# [3631/3800] 📥 Fetching goals for fixture 1208238
# [3632/3800] 📥 Fetching goals for fixture 1208242
# [3633/3800] 📥 Fetching goals for fixture 1208234
# [3634/3800] 📥 Fetching goals for fixture 1208233
# [3635/3800] 📥 Fetching goals for fixture 1208239
# [3636/3800] 📥 Fetching goals for fixture 1208236
# [3637/3800] 📥 Fetching goals for fixture 1208241
# [3638/3800] 📥 Fetching goals for fixture 1208237
# [3639/3800] 📥 Fetching goals for fixture 1208235
# [3640/3800] 📥 Fetching goals for fixture 1208243
# [3641/3800] 📥 Fetching goals for fixture 1208252
# [3642/3800] 📥 Fetching goals for fixture 1208248
# [3643/3800] 📥 Fetching goals for fixture 1208250
# [3644/3800] 📥 Fetching goals for fixture 1208245
# [3645/3800] 📥 Fetching goals for fixture 1208249
# [3646/3800] 📥 Fetching goals for fixture 1208251
# [3647/3800] 📥 Fetching goals for fixture 1208246
# [3648/3800] 📥 Fetching goals for fixture 1208244
# [3649/3800] 📥 Fetching goals for fixture 1208247
# [3650/3800] 📥 Fetching goals for fixture 1208261
# [3651/3800] 📥 Fetching goals for fixture 1208260
# [3652/3800] 📥 Fetching goals for fixture 1208253
# [3653/3800] 📥 Fetching goals for fixture 1208257
# [3654/3800] 📥 Fetching goals for fixture 1208258
# [3655/3800] 📥 Fetching goals for fixture 1208262
# [3656/3800] 📥 Fetching goals for fixture 1208259
# [3657/3800] 📥 Fetching goals for fixture 1208255
# [3658/3800] 📥 Fetching goals for fixture 1208254
# [3659/3800] 📥 Fetching goals for fixture 1208256
# [3660/3800] 📥 Fetching goals for fixture 1208166
# [3661/3800] 📥 Fetching goals for fixture 1208264
# [3662/3800] 📥 Fetching goals for fixture 1208267
# [3663/3800] 📥 Fetching goals for fixture 1208266
# [3664/3800] 📥 Fetching goals for fixture 1208270
# [3665/3800] 📥 Fetching goals for fixture 1208272
# [3666/3800] 📥 Fetching goals for fixture 1208269
# [3667/3800] 📥 Fetching goals for fixture 1208263
# [3668/3800] 📥 Fetching goals for fixture 1208265
# [3669/3800] 📥 Fetching goals for fixture 1208268
# [3670/3800] 📥 Fetching goals for fixture 1208271
# [3671/3800] 📥 Fetching goals for fixture 1208305
# [3672/3800] 📥 Fetching goals for fixture 1208279
# [3673/3800] 📥 Fetching goals for fixture 1208276
# [3674/3800] 📥 Fetching goals for fixture 1208273
# [3675/3800] 📥 Fetching goals for fixture 1208277
# [3676/3800] 📥 Fetching goals for fixture 1208282
# [3677/3800] 📥 Fetching goals for fixture 1208274
# [3678/3800] 📥 Fetching goals for fixture 1208278
# [3679/3800] 📥 Fetching goals for fixture 1208275
# [3680/3800] 📥 Fetching goals for fixture 1208281
# [3681/3800] 📥 Fetching goals for fixture 1208280
# [3682/3800] 📥 Fetching goals for fixture 1208288
# [3683/3800] 📥 Fetching goals for fixture 1208284
# [3684/3800] 📥 Fetching goals for fixture 1208289
# [3685/3800] 📥 Fetching goals for fixture 1208290
# [3686/3800] 📥 Fetching goals for fixture 1208292
# [3687/3800] 📥 Fetching goals for fixture 1208286
# [3688/3800] 📥 Fetching goals for fixture 1208283
# [3689/3800] 📥 Fetching goals for fixture 1208285
# [3690/3800] 📥 Fetching goals for fixture 1208291
# [3691/3800] 📥 Fetching goals for fixture 1208287
# [3692/3800] 📥 Fetching goals for fixture 1208299
# [3693/3800] 📥 Fetching goals for fixture 1208297
# [3694/3800] 📥 Fetching goals for fixture 1208294
# [3695/3800] 📥 Fetching goals for fixture 1208296
# [3696/3800] 📥 Fetching goals for fixture 1208293
# [3697/3800] 📥 Fetching goals for fixture 1208302
# [3698/3800] 📥 Fetching goals for fixture 1208300
# [3699/3800] 📥 Fetching goals for fixture 1208295
# [3700/3800] 📥 Fetching goals for fixture 1208298
# [3701/3800] 📥 Fetching goals for fixture 1208301
# [3702/3800] 📥 Fetching goals for fixture 1208312
# [3703/3800] 📥 Fetching goals for fixture 1208306
# [3704/3800] 📥 Fetching goals for fixture 1208310
# [3705/3800] 📥 Fetching goals for fixture 1208308
# [3706/3800] 📥 Fetching goals for fixture 1208303
# [3707/3800] 📥 Fetching goals for fixture 1208307
# [3708/3800] 📥 Fetching goals for fixture 1208304
# [3709/3800] 📥 Fetching goals for fixture 1208309
# [3710/3800] 📥 Fetching goals for fixture 1208317
# [3711/3800] 📥 Fetching goals for fixture 1208314
# [3712/3800] 📥 Fetching goals for fixture 1208316
# [3713/3800] 📥 Fetching goals for fixture 1208320
# [3714/3800] 📥 Fetching goals for fixture 1208313
# [3715/3800] 📥 Fetching goals for fixture 1208321
# [3716/3800] 📥 Fetching goals for fixture 1208319
# [3717/3800] 📥 Fetching goals for fixture 1208315
# [3718/3800] 📥 Fetching goals for fixture 1208322
# [3719/3800] 📥 Fetching goals for fixture 1208318
# [3720/3800] 📥 Fetching goals for fixture 1208326
# [3721/3800] 📥 Fetching goals for fixture 1208332
# [3722/3800] 📥 Fetching goals for fixture 1208325
# [3723/3800] 📥 Fetching goals for fixture 1208328
# [3724/3800] 📥 Fetching goals for fixture 1208323
# [3725/3800] 📥 Fetching goals for fixture 1208327
# [3726/3800] 📥 Fetching goals for fixture 1208331
# [3727/3800] 📥 Fetching goals for fixture 1208324
# [3728/3800] 📥 Fetching goals for fixture 1208330
# [3729/3800] 📥 Fetching goals for fixture 1208329
# [3730/3800] 📥 Fetching goals for fixture 1208338
# [3731/3800] 📥 Fetching goals for fixture 1208341
# [3732/3800] 📥 Fetching goals for fixture 1208335
# [3733/3800] 📥 Fetching goals for fixture 1208340
# [3734/3800] 📥 Fetching goals for fixture 1208334
# [3735/3800] 📥 Fetching goals for fixture 1208342
# [3736/3800] 📥 Fetching goals for fixture 1208337
# [3737/3800] 📥 Fetching goals for fixture 1208336
# [3738/3800] 📥 Fetching goals for fixture 1208339
# [3739/3800] 📥 Fetching goals for fixture 1208333
# [3740/3800] 📥 Fetching goals for fixture 1208311
# [3741/3800] 📥 Fetching goals for fixture 1208346
# [3742/3800] 📥 Fetching goals for fixture 1208352
# [3743/3800] 📥 Fetching goals for fixture 1208345
# [3744/3800] 📥 Fetching goals for fixture 1208344
# [3745/3800] 📥 Fetching goals for fixture 1208343
# [3746/3800] 📥 Fetching goals for fixture 1208350
# [3747/3800] 📥 Fetching goals for fixture 1208347
# [3748/3800] 📥 Fetching goals for fixture 1208348
# [3749/3800] 📥 Fetching goals for fixture 1208349
# [3750/3800] 📥 Fetching goals for fixture 1208351
# [3751/3800] 📥 Fetching goals for fixture 1208358
# [3752/3800] 📥 Fetching goals for fixture 1208354
# [3753/3800] 📥 Fetching goals for fixture 1208356
# [3754/3800] 📥 Fetching goals for fixture 1208359
# [3755/3800] 📥 Fetching goals for fixture 1208362
# [3756/3800] 📥 Fetching goals for fixture 1208361
# [3757/3800] 📥 Fetching goals for fixture 1208355
# [3758/3800] 📥 Fetching goals for fixture 1208353
# [3759/3800] 📥 Fetching goals for fixture 1208357
# [3760/3800] 📥 Fetching goals for fixture 1208360
# [3761/3800] 📥 Fetching goals for fixture 1208371
# [3762/3800] 📥 Fetching goals for fixture 1208364
# [3763/3800] 📥 Fetching goals for fixture 1208369
# [3764/3800] 📥 Fetching goals for fixture 1208370
# [3765/3800] 📥 Fetching goals for fixture 1208363
# [3766/3800] 📥 Fetching goals for fixture 1208372
# [3767/3800] 📥 Fetching goals for fixture 1208366
# [3768/3800] 📥 Fetching goals for fixture 1208365
# [3769/3800] 📥 Fetching goals for fixture 1208367
# [3770/3800] 📥 Fetching goals for fixture 1208368
# [3771/3800] 📥 Fetching goals for fixture 1208374
# [3772/3800] 📥 Fetching goals for fixture 1208382
# [3773/3800] 📥 Fetching goals for fixture 1208380
# [3774/3800] 📥 Fetching goals for fixture 1208375
# [3775/3800] 📥 Fetching goals for fixture 1208373
# [3776/3800] 📥 Fetching goals for fixture 1208378
# [3777/3800] 📥 Fetching goals for fixture 1208377
# [3778/3800] 📥 Fetching goals for fixture 1208381
# [3779/3800] 📥 Fetching goals for fixture 1208379
# [3780/3800] 📥 Fetching goals for fixture 1208376
# [3781/3800] 📥 Fetching goals for fixture 1208384
# [3782/3800] 📥 Fetching goals for fixture 1208387
# [3783/3800] 📥 Fetching goals for fixture 1208389
# [3784/3800] 📥 Fetching goals for fixture 1208392
# [3785/3800] 📥 Fetching goals for fixture 1208390
# [3786/3800] 📥 Fetching goals for fixture 1208385
# [3787/3800] 📥 Fetching goals for fixture 1208383
# [3788/3800] 📥 Fetching goals for fixture 1208386
# [3789/3800] 📥 Fetching goals for fixture 1208391
# [3790/3800] 📥 Fetching goals for fixture 1208388
# [3791/3800] 📥 Fetching goals for fixture 1208397
# [3792/3800] 📥 Fetching goals for fixture 1208398
# [3793/3800] 📥 Fetching goals for fixture 1208393
# [3794/3800] 📥 Fetching goals for fixture 1208394
# [3795/3800] 📥 Fetching goals for fixture 1208402
# [3796/3800] 📥 Fetching goals for fixture 1208396
# [3797/3800] 📥 Fetching goals for fixture 1208400
# [3798/3800] 📥 Fetching goals for fixture 1208401
# [3799/3800] 📥 Fetching goals for fixture 1208395
# [3800/3800] 📥 Fetching goals for fixture 1208399
# ✅ Goal fetch complete → goals_prem_2015_2024.csv
#        fixture_id  team_id          team_name minute
# 0          192297       33  Manchester United     22
# 1          192298       66        Aston Villa     72
# 2          192301       38            Watford     14
# 3          192301       45            Everton     76
# 4          192301       38            Watford     83
# ...           ...      ...                ...    ...
# 21535     1208395       48           West Ham     43
# 21536     1208395       57            Ipswich     52
# 21537     1208395       48           West Ham     55
# 21538     1208395       48           West Ham     87
# 21539     1208399       49            Chelsea     50
#
# [21540 rows x 4 columns]

# %%
df_meta = pd.read_csv("/content/fixture_meta_data.csv")
df_goals = pd.read_csv("/content/goals_prem_2015_2024.csv")

# %%
df_goals.tail()
# Out:
#        fixture_id  team_id team_name minute
# 21535     1208395       48  West Ham     43
# 21536     1208395       57   Ipswich     52
# 21537     1208395       48  West Ham     55
# 21538     1208395       48  West Ham     87
# 21539     1208399       49   Chelsea     50

# %% [markdown]
# # **Del 3: Omvandla och slå samman målstatistik**

# %% [markdown]
# ## Syfte
# Kombinera matchmetadata (Del 1) med detaljerad målstatistik (Del 2)
# till en enhetlig dataset där varje match har en lista över målminuter.
#
# ## Vad görs här?
#
# ### Steg 1: `build_df_goals_compact()`
# Denna funktion omvandlar rå måldata till kompakt format:
#
# **Input**:
# ```
# fixture_id | team_id | minute
# 1234       | 33      | 22
# 1234       | 47      | 76
# ```
#
# **Output**:
# ```
# fixture_id | home_goal_minutes | away_goal_minutes
# 1234       | [22]              | [76]
# ```
#
# **Processteg**:
# 1. Parsear minut-strängar ("90+5" → 90)
# 2. Matchar team_id mot home_team_id/away_team_id
# 3. Grupperar mål per match och lag
# 4. Skapar sorterade listor av målminuter
# 5. **Kritiskt**: Bevarar 0-0 matcher som tomma listor []
#
# ### Steg 2: Merge med metadata
# Slår ihop kompakt måldata med ursprungliga matchdata:
# - Alla kolumner från `fixture_meta_data.csv` behålls
# - Två nya kolumner läggs till:
#   - `home_goal_minutes`: Lista med hemmalags målminuter
#   - `away_goal_minutes`: Lista med bortalags målminuter
#
# ## Exempel på resultat
# ```
# fixture_id: 192297
# home_team: Manchester United
# away_team: Tottenham
# ft_home_goals: 1
# ft_away_goals: 0
# home_goal_minutes: [22]        ← Mål i minut 22
# away_goal_minutes: []          ← Inga mål
# ```
#
# ## Varför listor?
# Listor tillåter senare analys av:
# - Antal tidiga mål (0-15 min)
# - Antal första halvlek mål (0-45 min)
# - Målfördelning över tid
#
# ## Fil som skapas
# - `complete_fixture_data.csv` - Komplett dataset med alla 3800 matcher
#   och deras respektive målminuter

# %%
import pandas as pd
import numpy as np

def build_df_goals_compact(df_goals: pd.DataFrame, df_meta: pd.DataFrame) -> pd.DataFrame:
    goals = df_goals.copy()
    meta = df_meta[["fixture_id","home_team_id","away_team_id"]].drop_duplicates().copy()

    # Base: ALL fixtures (ensures 0-0 fixtures still appear)
    base = meta[["fixture_id"]].drop_duplicates().copy()

    # --- Ensure IDs are numeric (prevents string-vs-int comparisons) ---
    for c in ["fixture_id", "team_id"]:
        goals[c] = pd.to_numeric(goals[c], errors="coerce")
    for c in ["fixture_id", "home_team_id", "away_team_id"]:
        meta[c] = pd.to_numeric(meta[c], errors="coerce")

    goals = goals.dropna(subset=["fixture_id","team_id"]).copy()
    meta = meta.dropna(subset=["fixture_id","home_team_id","away_team_id"]).copy()

    goals["fixture_id"] = goals["fixture_id"].astype(int)
    goals["team_id"] = goals["team_id"].astype(int)
    meta["fixture_id"] = meta["fixture_id"].astype(int)
    meta["home_team_id"] = meta["home_team_id"].astype(int)
    meta["away_team_id"] = meta["away_team_id"].astype(int)
    base["fixture_id"] = pd.to_numeric(base["fixture_id"], errors="coerce").astype(int)

    # --- Parse minute (handles "90+5") ---
    m = goals["minute"].astype(str)
    goals["minute_main"] = pd.to_numeric(m.str.split("+").str[0], errors="coerce")
    goals = goals.dropna(subset=["minute_main"]).copy()
    goals["minute_main"] = goals["minute_main"].astype(int)

    # --- Attach home/away ---
    goals = goals.merge(meta, on="fixture_id", how="left")

    goals["side"] = None
    goals.loc[goals["team_id"] == goals["home_team_id"], "side"] = "home"
    goals.loc[goals["team_id"] == goals["away_team_id"], "side"] = "away"
    goals = goals.dropna(subset=["side"]).copy()

    # --- Aggregate minutes into sorted lists ---
    agg = (
        goals.sort_values("minute_main")
             .groupby(["fixture_id","side"])["minute_main"]
             .apply(list)
             .unstack()                      # keep NaN for missing sides
             .reset_index()
             .rename(columns={"home": "home_goal_minutes", "away": "away_goal_minutes"})
    )

    # --- Left join onto ALL fixtures so 0-0 games are included ---
    out = base.merge(agg, on="fixture_id", how="left")

    # Fill missing lists with empty lists
    out["home_goal_minutes"] = out["home_goal_minutes"].apply(lambda x: x if isinstance(x, list) else [])
    out["away_goal_minutes"] = out["away_goal_minutes"].apply(lambda x: x if isinstance(x, list) else [])

    return out

# %%
df_goals_compact = build_df_goals_compact(df_goals, df_meta)
df_goals_compact.tail()
# Out:
#       fixture_id                 away_goal_minutes home_goal_minutes
# 3795     1208396                            [9, 9]          [84, 84]
# 3796     1208400                  [43, 43, 90, 90]          [56, 56]
# 3797     1208401  [51, 51, 64, 64, 88, 88, 90, 90]          [17, 17]
# 3798     1208395          [43, 43, 55, 55, 87, 87]          [52, 52]
# 3799     1208399                          [50, 50]                []

# %%
df_meta_merged = df_meta.merge(df_goals_compact, on="fixture_id", how="left")

# %%
df_meta_merged.head()
# Out:
#    fixture_id                       date  season  home_team_id  \
# 0      192297  2015-08-08T11:45:00+00:00    2015            33
# 1      192298  2015-08-08T14:00:00+00:00    2015            35
# 2      192301  2015-08-08T14:00:00+00:00    2015            45
# 3      192300  2015-08-08T14:00:00+00:00    2015            46
# 4      192299  2015-08-08T14:00:00+00:00    2015            71
#
#       home_team_name  away_team_id  away_team_name  ht_home_goals  \
# 0  Manchester United            47       Tottenham              1
# 1        Bournemouth            66     Aston Villa              0
# 2            Everton            38         Watford              0
# 3          Leicester           746      Sunderland              3
# 4            Norwich            52  Crystal Palace              0
#
#    ht_away_goals  ft_home_goals  ft_away_goals home_winner away_winner  \
# 0              0              1              0        True       False
# 1              0              0              1       False        True
# 2              1              2              2         NaN         NaN
# 3              0              4              2        True       False
# 4              1              1              3       False        True
#
#    total_goals_ht  total_goals_ft  fulltime_over_2_5  btts  second_half_goals  \
# 0               1               1                  0     0                  0
# 1               0               1                  0     0                  1
# 2               1               4                  1     1                  3
# 3               3               6                  1     1                  3
# 4               1               4                  1     1                  3
#
#           away_goal_minutes                 home_goal_minutes
# 0                        []                          [22, 22]
# 1                  [72, 72]                                []
# 2          [14, 14, 83, 83]                  [76, 76, 86, 86]
# 3          [60, 60, 71, 71]  [11, 11, 18, 18, 25, 25, 66, 66]
# 4  [39, 39, 49, 49, 90, 90]                          [69, 69]

# %%
df_meta_merged.to_csv("complete_fixture_data.csv", index=False)

# %% [markdown]
# # **Del 4: Feature engineering med rullande medelvärden**

# %% [markdown]
# ## Syfte
# Omvandla historiska matchresultat till attribut som är **kända innan avspark**.
#
# ## KRITISKT: Undvika dataläckage
# **Dataläckage** = när modellen får information som inte skulle vara tillgänglig
# vid prediktionstillfället.
#
# **Exempel på läckage** ❌:
# - Använda `ft_home_goals` direkt → detta är matchens slutresultat!
#
# **Korrekt approach** ✅:
# - Använda `home_avg_ft_gf_last3` → genomsnitt av de TRE SENASTE matcherna
#
# ## Vad görs här?
#
# ### Steg 1: Sortera matcher temporalt
# ```python
# df = df.sort_values(["date", "fixture_id"])
# ```
# Säkerställer att matcher processas i kronologisk ordning.
#
# ### Steg 2: Skapa team-match view
# Varje match blir två rader (en för hemma, en för borta):
# ```
# Match: Man Utd 1-0 Tottenham
# → Rad 1: team_id=33 (Man Utd), side=home, pts=3, ft_gf=1, ft_ga=0
# → Rad 2: team_id=47 (Tottenham), side=away, pts=0, ft_gf=0, ft_ga=1
# ```
#
# ### Steg 3: Beräkna rullande medelvärden
# **Nyckelrad**:
# ```python
# .groupby("team_id")[col].transform(
#     lambda s: s.shift(1).rolling(window, min_periods=1).mean()
# )
# ```
#
# **Vad gör `.shift(1)`?**
# - Flyttar serien ett steg BAKÅT i tiden
# - Betyder att match N använder data från matcher N-1, N-2, N-3
# - **Detta förhindrar dataläckage!**
#
# **Exempel för Manchester United**:
# ```
# Match 1: pts=3 → avg_pts_last3 = NaN (ingen historik)
# Match 2: pts=0 → avg_pts_last3 = 3.0 (endast match 1)
# Match 3: pts=1 → avg_pts_last3 = 1.5 (match 1+2)
# Match 4: pts=3 → avg_pts_last3 = 1.33 (match 1+2+3)
# Match 5: pts=0 → avg_pts_last3 = 1.33 (match 2+3+4) ← window=3
# ```
#
# ### Steg 4: Attribut som beräknas (window=3)
#
# **Allmän form**:
# - `avg_pts_last3`: Genomsnittliga poäng
# - `pts_sum_last3`: Total poängsumma
# - `avg_ft_gf_last3`: Genomsnittliga gjorda mål (fulltime)
# - `avg_ft_ga_last3`: Genomsnittliga insläppta mål (fulltime)
# - `avg_ht_gf_last3`: Genomsnittliga gjorda mål (halvtid)
# - `avg_ht_ga_last3`: Genomsnittliga insläppta mål (halvtid)
#
# **Tidiga mål (från målminuter)**:
# - `avg_scored_0_15_last3`: Genomsnittliga mål i minut 0-15
# - `avg_scored_1H_last3`: Genomsnittliga mål i första halvlek
#
# ### Steg 5: Split till home/away
# Attributen delas upp så att varje match har:
# - `home_avg_ft_gf_last3` - hemmalags genomsnitt
# - `away_avg_ft_gf_last3` - bortalags genomsnitt
#
# ### Steg 6: Merge tillbaka till fixture-nivå
# Resultatet blir EN rad per match med 18 attribut:
# - 5 identifierare (fixture_id, date, season, home_team_id, away_team_id)
# - 6 hemma-attribut (avg_pts, avg_gf, avg_ga, osv.)
# - 6 borta-attribut (samma som hemma)
# - 4 tidiga mål-attribut (0-15 min, 1H mål)
# - 1 target (fulltime_over_2_5)
#
# ## Rensning av data
# - Droppar rader med NaN (första matcherna per säsong saknar historik)
# - Droppar rader med inf-värden (division med noll, etc.)
# - **Slutresultat**: 3776 matcher (förlorade 24 pga saknad historik)
#
# ## Fil som skapas
# - Ingen explicit fil, men `df_pre_match` innehåller färdiga features
# - Detta är den FINALA dataset som används för träning/test

# %%
import pandas as pd
import numpy as np
df = pd.read_csv("complete_fixture_data.csv")

# %%
df["date"] = pd.to_datetime(df["date"], errors="coerce").dt.normalize()
df.head()
# Out:
#    fixture_id                      date  season  home_team_id  \
# 0      192297 2015-08-08 00:00:00+00:00    2015            33
# 1      192298 2015-08-08 00:00:00+00:00    2015            35
# 2      192301 2015-08-08 00:00:00+00:00    2015            45
# 3      192300 2015-08-08 00:00:00+00:00    2015            46
# 4      192299 2015-08-08 00:00:00+00:00    2015            71
#
#       home_team_name  away_team_id  away_team_name  ht_home_goals  \
# 0  Manchester United            47       Tottenham              1
# 1        Bournemouth            66     Aston Villa              0
# 2            Everton            38         Watford              0
# 3          Leicester           746      Sunderland              3
# 4            Norwich            52  Crystal Palace              0
#
#    ht_away_goals  ft_home_goals  ft_away_goals home_winner away_winner  \
# 0              0              1              0        True       False
# 1              0              0              1       False        True
# 2              1              2              2         NaN         NaN
# 3              0              4              2        True       False
# 4              1              1              3       False        True
#
#    total_goals_ht  total_goals_ft  fulltime_over_2_5  btts  second_half_goals  \
# 0               1               1                  0     0                  0
# 1               0               1                  0     0                  1
# 2               1               4                  1     1                  3
# 3               3               6                  1     1                  3
# 4               1               4                  1     1                  3
#
#           away_goal_minutes                 home_goal_minutes
# 0                        []                          [22, 22]
# 1                  [72, 72]                                []
# 2          [14, 14, 83, 83]                  [76, 76, 86, 86]
# 3          [60, 60, 71, 71]  [11, 11, 18, 18, 25, 25, 66, 66]
# 4  [39, 39, 49, 49, 90, 90]                          [69, 69]

# %%
print("Rows:", len(df))
print("Date range:", df["date"].min(), "->", df["date"].max())
# Out:
# Rows: 3800
# Date range: 2015-08-08 00:00:00+00:00 -> 2025-05-25 00:00:00+00:00

# %%
goal_cols = ["ht_home_goals","ht_away_goals","ft_home_goals","ft_away_goals"]
df[goal_cols] = df[goal_cols].apply(pd.to_numeric, errors="coerce")

# sort in match order (fixture_id tie-breaker helps stability)
df = df.sort_values(["date", "fixture_id"]).reset_index(drop=True)

print(df[["fixture_id","date"]].head(10))
print("\nAny missing goals?", df[goal_cols].isna().any())
# Out:
#    fixture_id                      date
# 0      192297 2015-08-08 00:00:00+00:00
# 1      192298 2015-08-08 00:00:00+00:00
# 2      192299 2015-08-08 00:00:00+00:00
# 3      192300 2015-08-08 00:00:00+00:00
# 4      192301 2015-08-08 00:00:00+00:00
# 5      192302 2015-08-08 00:00:00+00:00
# 6      192303 2015-08-09 00:00:00+00:00
# 7      192304 2015-08-09 00:00:00+00:00
# 8      192305 2015-08-09 00:00:00+00:00
# 9      192306 2015-08-10 00:00:00+00:00
#
# Any missing goals? ht_home_goals    False
# ht_away_goals    False
# ft_home_goals    False
# ft_away_goals    False
# dtype: bool

# %%
# FT points
home_pts = np.select(
    [df["ft_home_goals"] > df["ft_away_goals"], df["ft_home_goals"] == df["ft_away_goals"]],
    [3, 1],
    default=0
)
away_pts = np.select(
    [df["ft_away_goals"] > df["ft_home_goals"], df["ft_away_goals"] == df["ft_home_goals"]],
    [3, 1],
    default=0
)

home = pd.DataFrame({
    "fixture_id": df["fixture_id"],
    "date": df["date"],
    "team_id": df["home_team_id"],
    "side": "home",
    "pts": home_pts,
    "ht_gf": df["ht_home_goals"],
    "ht_ga": df["ht_away_goals"],
    "ft_gf": df["ft_home_goals"],
    "ft_ga": df["ft_away_goals"],
})

away = pd.DataFrame({
    "fixture_id": df["fixture_id"],
    "date": df["date"],
    "team_id": df["away_team_id"],
    "side": "away",
    "pts": away_pts,
    "ht_gf": df["ht_away_goals"],
    "ht_ga": df["ht_home_goals"],
    "ft_gf": df["ft_away_goals"],
    "ft_ga": df["ft_home_goals"],
})

team_matches = pd.concat([home, away], ignore_index=True)
team_matches = team_matches.sort_values(["team_id","date","fixture_id"]).reset_index(drop=True)

print("Team-match rows (should be 2x fixtures):", len(team_matches), "vs", 2*len(df))
team_matches.head(10)
# Out:
# Team-match rows (should be 2x fixtures): 7600 vs 7600
#    fixture_id                      date  team_id  side  pts  ht_gf  ht_ga  \
# 0      192297 2015-08-08 00:00:00+00:00       33  home    3      1      0
# 1      192307 2015-08-14 00:00:00+00:00       33  away    3      1      0
# 2      192317 2015-08-22 00:00:00+00:00       33  home    1      0      0
# 3      192336 2015-08-30 00:00:00+00:00       33  away    0      0      0
# 4      192343 2015-09-12 00:00:00+00:00       33  home    3      0      0
# 5      192355 2015-09-20 00:00:00+00:00       33  away    3      1      1
# 6      192362 2015-09-26 00:00:00+00:00       33  home    3      1      0
# 7      192375 2015-10-04 00:00:00+00:00       33  away    0      0      3
# 8      192381 2015-10-17 00:00:00+00:00       33  away    3      2      0
# 9      192394 2015-10-25 00:00:00+00:00       33  home    1      0      0
#
#    ft_gf  ft_ga
# 0      1      0
# 1      1      0
# 2      0      0
# 3      1      2
# 4      3      1
# 5      3      2
# 6      3      0
# 7      0      3
# 8      3      0
# 9      0      0

# %%
window = 3

# --- rolling averages (PRE-match) in team_matches ---
for col, out in [
    ("pts",   f"avg_pts_last{window}"),
    ("ht_gf", f"avg_ht_gf_last{window}"),
    ("ht_ga", f"avg_ht_ga_last{window}"),
    ("ft_gf", f"avg_ft_gf_last{window}"),
    ("ft_ga", f"avg_ft_ga_last{window}"),
]:
    team_matches[out] = (
        team_matches
        .groupby("team_id")[col]
        .transform(lambda s: s.shift(1).rolling(window, min_periods=1).mean())
    )

team_matches[f"pts_sum_last{window}"] = (
    team_matches
    .groupby("team_id")["pts"]
    .transform(lambda s: s.shift(1).rolling(window, min_periods=1).sum())
)

feat_cols = [
    "fixture_id", "side",
    f"avg_pts_last{window}", f"pts_sum_last{window}",
    f"avg_ht_gf_last{window}", f"avg_ht_ga_last{window}",
    f"avg_ft_gf_last{window}", f"avg_ft_ga_last{window}",
]

# --- split to home / away and rename columns ---
home_feats = team_matches[team_matches["side"]=="home"][feat_cols].drop(columns=["side"]).rename(columns={
    f"avg_pts_last{window}":     f"home_avg_pts_last{window}",
    f"pts_sum_last{window}":     f"home_pts_sum_last{window}",
    f"avg_ht_gf_last{window}":   f"home_avg_ht_gf_last{window}",
    f"avg_ht_ga_last{window}":   f"home_avg_ht_ga_last{window}",
    f"avg_ft_gf_last{window}":   f"home_avg_ft_gf_last{window}",
    f"avg_ft_ga_last{window}":   f"home_avg_ft_ga_last{window}",
})

away_feats = team_matches[team_matches["side"]=="away"][feat_cols].drop(columns=["side"]).rename(columns={
    f"avg_pts_last{window}":     f"away_avg_pts_last{window}",
    f"pts_sum_last{window}":     f"away_pts_sum_last{window}",
    f"avg_ht_gf_last{window}":   f"away_avg_ht_gf_last{window}",
    f"avg_ht_ga_last{window}":   f"away_avg_ht_ga_last{window}",
    f"avg_ft_gf_last{window}":   f"away_avg_ft_gf_last{window}",
    f"avg_ft_ga_last{window}":   f"away_avg_ft_ga_last{window}",
})

# --- merge back into fixture-level df ---
df_roll = df.merge(home_feats, on="fixture_id", how="left").merge(away_feats, on="fixture_id", how="left")

print("Rows preserved?", len(df_roll), "==", len(df))
df_roll[[ "fixture_id","date","home_team_id","away_team_id",
          f"home_avg_ft_gf_last{window}", f"away_avg_ft_gf_last{window}",
          f"home_pts_sum_last{window}", f"away_pts_sum_last{window}" ]].tail()
# Out:
# Rows preserved? 3800 == 3800
#       fixture_id                      date  home_team_id  away_team_id  \
# 3795     1208398 2025-05-25 00:00:00+00:00            34            45
# 3796     1208399 2025-05-25 00:00:00+00:00            65            49
# 3797     1208400 2025-05-25 00:00:00+00:00            41            42
# 3798     1208401 2025-05-25 00:00:00+00:00            47            51
# 3799     1208402 2025-05-25 00:00:00+00:00            39            55
#
#       home_avg_ft_gf_last3  away_avg_ft_gf_last3  home_pts_sum_last3  \
# 3795              1.000000              2.333333                 4.0
# 3796              1.666667              1.333333                 5.0
# 3797              0.000000              1.333333                 1.0
# 3798              0.333333              2.000000                 1.0
# 3799              0.666667              2.333333                 0.0
#
#       away_pts_sum_last3
# 3795                 7.0
# 3796                 6.0
# 3797                 4.0
# 3798                 7.0
# 3799                 6.0

# %%
import ast

def parse_and_clean_goal_minutes(x):
    if pd.isna(x):
        return []
    if isinstance(x, list):
        raw = x
    else:
        try:
            raw = ast.literal_eval(x)   # turns "[9]" → [9]
        except:
            return []

    out = []
    for m in raw:
        try:
            out.append(int(str(m).split("+")[0]))
        except:
             print(f"⚠️ Failed to parse goal minute {m!r}: {e}")
    return out

df["home_goal_minutes"] = df["home_goal_minutes"].apply(parse_and_clean_goal_minutes)
df["away_goal_minutes"] = df["away_goal_minutes"].apply(parse_and_clean_goal_minutes)

# %%
def count_in_window(minutes, start, end):
    return sum(start <= m < end for m in minutes)

df["home_goals_0_15"] = df["home_goal_minutes"].apply(lambda x: count_in_window(x, 0, 15))
df["home_goals_1H"]   = df["home_goal_minutes"].apply(lambda x: count_in_window(x, 0, 45))

df["away_goals_0_15"] = df["away_goal_minutes"].apply(lambda x: count_in_window(x, 0, 15))
df["away_goals_1H"]   = df["away_goal_minutes"].apply(lambda x: count_in_window(x, 0, 45))

# %%
home_tm = pd.DataFrame({
    "fixture_id": df["fixture_id"],
    "date": df["date"],
    "team_id": df["home_team_id"],
    "side": "home",
    "scored_0_15": df["home_goals_0_15"],
    "scored_1H": df["home_goals_1H"],
})

away_tm = pd.DataFrame({
    "fixture_id": df["fixture_id"],
    "date": df["date"],
    "team_id": df["away_team_id"],
    "side": "away",
    "scored_0_15": df["away_goals_0_15"],
    "scored_1H": df["away_goals_1H"],
})

team_time = (
    pd.concat([home_tm, away_tm], ignore_index=True)
      .sort_values(["team_id","date","fixture_id"])
      .reset_index(drop=True)
)

# %%
window = 3

for col in ["scored_0_15", "scored_1H"]:
    team_time[f"avg_{col}_last{window}"] = (
        team_time
        .groupby("team_id")[col]
        .transform(lambda s: s.shift(1).rolling(window, min_periods=1).mean())
    )

# %%
home_roll = team_time[team_time["side"]=="home"][
    ["fixture_id",
     f"avg_scored_0_15_last{window}",
     f"avg_scored_1H_last{window}"]
].rename(columns={
    f"avg_scored_0_15_last{window}": f"home_avg_scored_0_15_last{window}",
    f"avg_scored_1H_last{window}":   f"home_avg_scored_1H_last{window}",
})

away_roll = team_time[team_time["side"]=="away"][
    ["fixture_id",
     f"avg_scored_0_15_last{window}",
     f"avg_scored_1H_last{window}"]
].rename(columns={
    f"avg_scored_0_15_last{window}": f"away_avg_scored_0_15_last{window}",
    f"avg_scored_1H_last{window}":   f"away_avg_scored_1H_last{window}",
})

df_final = (
    df_roll
    .merge(home_roll, on="fixture_id", how="left")
    .merge(away_roll, on="fixture_id", how="left")
)

# %%
df_final.columns.to_list()
# Out:
# ['fixture_id',
#  'date',
#  'season',
#  'home_team_id',
#  'home_team_name',
#  'away_team_id',
#  'away_team_name',
#  'ht_home_goals',
#  'ht_away_goals',
#  'ft_home_goals',
#  'ft_away_goals',
#  'home_winner',
#  'away_winner',
#  'total_goals_ht',
#  'total_goals_ft',
#  'fulltime_over_2_5',
#  'btts',
#  'second_half_goals',
#  'away_goal_minutes',
#  'home_goal_minutes',
#  'home_avg_pts_last3',
#  'home_pts_sum_last3',
#  'home_avg_ht_gf_last3',
#  'home_avg_ht_ga_last3',
#  'home_avg_ft_gf_last3',
#  'home_avg_ft_ga_last3',
#  'away_avg_pts_last3',
#  'away_pts_sum_last3',
#  'away_avg_ht_gf_last3',
#  'away_avg_ht_ga_last3',
#  'away_avg_ft_gf_last3',
#  'away_avg_ft_ga_last3',
#  'home_avg_scored_0_15_last3',
#  'home_avg_scored_1H_last3',
#  'away_avg_scored_0_15_last3',
#  'away_avg_scored_1H_last3']

# %%
prematch_features = [
    # identifiers / ordering
    "fixture_id",
    "date",
    "season",
    "home_team_id",
    "away_team_id",

    # rolling form & goals
    "home_avg_pts_last3",
    "home_pts_sum_last3",
    "home_avg_ht_gf_last3",
    "home_avg_ht_ga_last3",
    "home_avg_ft_gf_last3",
    "home_avg_ft_ga_last3",

    "away_avg_pts_last3",
    "away_pts_sum_last3",
    "away_avg_ht_gf_last3",
    "away_avg_ht_ga_last3",
    "away_avg_ft_gf_last3",
    "away_avg_ft_ga_last3",

    # rolling early-goal tendencies
    "home_avg_scored_0_15_last3",
    "home_avg_scored_1H_last3",
    "away_avg_scored_0_15_last3",
    "away_avg_scored_1H_last3",
]

df_pre_match = df_final[prematch_features + ["fulltime_over_2_5"]].copy()

# %%
# columns with at least one NaN + count
df_pre_match.isna().sum().loc[lambda s: s > 0]
# Out:
# home_avg_pts_last3            18
# home_pts_sum_last3            18
# home_avg_ht_gf_last3          18
# home_avg_ht_ga_last3          18
# home_avg_ft_gf_last3          18
# home_avg_ft_ga_last3          18
# away_avg_pts_last3            16
# away_pts_sum_last3            16
# away_avg_ht_gf_last3          16
# away_avg_ht_ga_last3          16
# away_avg_ft_gf_last3          16
# away_avg_ft_ga_last3          16
# home_avg_scored_0_15_last3    18
# home_avg_scored_1H_last3      18
# away_avg_scored_0_15_last3    16
# away_avg_scored_1H_last3      16
# dtype: int64

# %%
# drop rows with NaNs in any column
df_pre_match = df_pre_match.dropna().reset_index(drop=True)
len(df_pre_match)
# Out:
# 3776

# %%
df_pre_match = df_pre_match.replace([np.inf, -np.inf], np.nan).dropna().reset_index(drop=True)

# %%
df_pre_match.tail()
# Out:
#       fixture_id                      date  season  home_team_id  \
# 3771     1208398 2025-05-25 00:00:00+00:00    2024            34
# 3772     1208399 2025-05-25 00:00:00+00:00    2024            65
# 3773     1208400 2025-05-25 00:00:00+00:00    2024            41
# 3774     1208401 2025-05-25 00:00:00+00:00    2024            47
# 3775     1208402 2025-05-25 00:00:00+00:00    2024            39
#
#       away_team_id  home_avg_pts_last3  home_pts_sum_last3  \
# 3771            45            1.333333                 4.0
# 3772            49            1.666667                 5.0
# 3773            42            0.333333                 1.0
# 3774            51            0.333333                 1.0
# 3775            55            0.000000                 0.0
#
#       home_avg_ht_gf_last3  home_avg_ht_ga_last3  home_avg_ft_gf_last3  ...  \
# 3771              0.333333              0.333333              1.000000  ...
# 3772              0.666667              0.333333              1.666667  ...
# 3773              0.000000              1.333333              0.000000  ...
# 3774              0.333333              0.666667              0.333333  ...
# 3775              0.333333              1.333333              0.666667  ...
#
#       away_pts_sum_last3  away_avg_ht_gf_last3  away_avg_ht_ga_last3  \
# 3771                 7.0              1.666667              0.666667
# 3772                 6.0              0.333333              0.333333
# 3773                 4.0              0.333333              0.666667
# 3774                 7.0              1.000000              0.666667
# 3775                 6.0              1.666667              0.666667
#
#       away_avg_ft_gf_last3  away_avg_ft_ga_last3  home_avg_scored_0_15_last3  \
# 3771              2.333333              1.000000                    0.666667
# 3772              1.333333              1.000000                    0.666667
# 3773              1.333333              1.333333                    0.000000
# 3774              2.000000              1.000000                    0.000000
# 3775              2.333333              2.000000                    0.000000
#
#       home_avg_scored_1H_last3  away_avg_scored_0_15_last3  \
# 3771                  0.666667                    0.666667
# 3772                  1.333333                    0.666667
# 3773                  0.000000                    0.000000
# 3774                  0.666667                    0.000000
# 3775                  0.666667                    0.000000
#
#       away_avg_scored_1H_last3  fulltime_over_2_5
# 3771                  2.000000                  0
# 3772                  0.666667                  0
# 3773                  0.666667                  1
# 3774                  2.000000                  1
# 3775                  4.000000                  0
#
# [5 rows x 22 columns]

# %% [markdown]
# # **Del 5: Träna och utvärdera modeller**

# %% [markdown]
# ## Syfte
# Träna två maskininlärningsmodeller och jämföra deras förmåga att förutsäga över 2.5 mål baserat på pre-match-attribut.
#
# ## Val av modeller
#
# ### 1. Logistic Regression (Baseline)
# **Varför?**
# - Enkel, tolkbar modell
# - Linjära beslutsregler
# - Naturliga sannolikhetsutskrifter
# - Fungerar som "minimum viable model"
#
# **Hyperparametrar som optimeras**:
# - `C`: Regulariseringsstyrka (söks i intervallet 0.001-10.0)
# - `penalty='l2'`: L2-regularisering (Ridge)
# - `solver='lbfgs'`: Effektiv optimizer för logistisk regression
# - `max_iter=5000`: Tillräckligt för konvergens
# - `class_weight='balanced'`: Kompenserar för 54/46 klassbalans
#
# ### 2. Random Forest (Icke-linjär)
# **Varför?**
# - Kan fånga icke-linjära samband
# - Hanterar interaktioner mellan attribut
# - Robust mot outliers
# - Ger feature importance
#
# **Hyperparametrar som optimeras**:
# - `n_estimators`: Antal beslutsträd (söks i intervallet 150-500)
# - `max_depth`: Maximalt trädjup (söks i intervallet 3-10)
# - `min_samples_leaf`: Minsta antal exempel per löv (söks i intervallet 10-60)
# - `min_samples_split`: Minsta antal exempel för split (söks i intervallet 10-80)
# - `max_features`: Antal features per split ('sqrt' eller 'log2')
# - `class_weight='balanced'`: Kompenserar för klassbalans
#
# ## Hyperparameteroptimering
#
# **Metod: Bayesian Optimization**
#
# I stället för att manuellt välja hyperparametrar används Bayesian optimization via `BayesSearchCV` från scikit-optimize. Denna metod:
# - Söker intelligentare än grid search eller random search
# - Utforskar parameterrymden strategiskt
# - Kräver färre iterationer (30 istället för 100+ vid grid search)
# - Optimerar för `neg_brier_score` (negativ Brier score)
#
# **Korsvalidering: Time Series Split**
#
# Eftersom fotbollsdata har temporal struktur används `TimeSeriesSplit` med 3 splits:
# ```python
# tscv = TimeSeriesSplit(n_splits=3)
# ```
#
# Detta säkerställer att:
# - Träningsdata alltid kommer före valideringsdata
# - Ingen framtida information läcker bakåt i tiden
# - Validering simulerar verklig prediktering
#
# **Optimeringsprocess**:
#
# 1. **Random Forest**: BayesSearchCV söker genom 30 iterationer för att hitta bästa kombination av antal träd, djup och split-kriterier
# 2. **Logistic Regression**: BayesSearchCV söker genom 30 iterationer för att hitta optimal regulariseringsstyrka
#
# Varje iteration utvärderas med 3-fold time series cross-validation på träningsdatan.
#
# ## Train/Test Split
#
# **Strategi: Temporal split**
# ```python
# test_seasons = [2023, 2024]  # Senaste två säsongerna
# ```
#
# **Varför inte random split?**
# - Fotbollsdata har temporal struktur
# - Vi vill simulera "prediktera framtida matcher"
# - Random split skulle kunna läcka framtida info till träning
#
# **Resultat**:
# - Träningsdata: 3018 matcher (säsong 2015-2022)
# - Testdata: 758 matcher (säsong 2023-2024)
# - Features: 18 stycken
#
# ## Träning av slutgiltiga modeller
#
# Efter Bayesian optimization tränas de slutgiltiga modellerna med de bästa hyperparametrarna:
#
# **Random Forest**:
# ```python
# rf = RandomForestClassifier(
#     **best_rf_params,
#     random_state=42,
#     n_jobs=-1,
#     class_weight="balanced",
# )
# rf.fit(X_train, y_train)
# ```
#
# **Logistic Regression**:
# ```python
# lr = LogisticRegression(
#     **best_lr_params,
#     solver="lbfgs",
#     max_iter=5000,
#     class_weight="balanced",
# )
# lr.fit(X_train, y_train)
# ```
#
# Båda modellerna tränas på hela träningsdataset (3018 matcher) och utvärderas på testdata (758 matcher).
#
# ## Utvärderingsmått
#
# ### 1. ROC-AUC (Receiver Operating Characteristic - Area Under Curve)
# **Vad mäts**: Modellens förmåga att rangordna matcher efter sannolikhet
# - **1.0** = Perfekt separation mellan klasser
# - **0.5** = Lika bra som slumpen
# - **< 0.5** = Sämre än slumpen
#
# **Tolkning**: Om ROC-AUC = 0.51 → modellen är knappt bättre än att gissa.
#
# ### 2. Accuracy (Noggrannhet)
# **Vad mäts**: Andel korrekta prediktioner
# ```
# Accuracy = (Rätt förutsagda) / (Totalt antal)
# ```
#
# **Tolkning**: Om Accuracy = 52% vid 54/46 klassbalans → inte mycket bättre än majoritetsklass.
#
# ### 3. Brier Score
# **Vad mäts**: Genomsnittligt kvadrerat fel mellan sannolikhet och utfall
# ```
# Brier = mean((p_pred - y_true)²)
# ```
# - **0.0** = Perfekta sannolikheter
# - **0.25** = Neutralt (alltid gissa 0.5)
#
# **Tolkning**: Om Brier = 0.25 → modellens sannolikheter är inte informativa.
#
# ### 4. Precision@5
# **Vad mäts**: Andel korrekta bland de 5 högst rankade matcherna
# ```
# Precision@5 = (Antal över 2.5 bland top-5) / 5
# ```
#
# **Tolkning**: Om Precision@5 = 0.6 → 3 av 5 högst rankade matcher var faktiskt över 2.5 mål.
#
# **Varför viktigt?** I ett beslutsstödsystem vill vi kunna säga: "Här är veckans 5 bästa matcher" och ha rätt i majoriteten av fallen.
#
# ## Resultat
# ```
#                       ROC_AUC  Accuracy  Brier  Precision@5
# Model
# RF (Bayes-opt)          0.506    0.504   0.25          1.0
# LogReg (Bayes-opt)      0.507    0.517   0.25          1.0
# ```
#
#
# ## Tolkning av resultat
#
# ### ROC-AUC ~0.5
# ❌ **Modellerna kan inte rangordna matcher bättre än slumpen**
# - Även med optimerade hyperparametrar saknar attributen tillräcklig prediktiv kraft
# - Pre-match-statistik är inte tillräcklig
#
# ### Accuracy ~52%
# ⚠️ **Bara marginellt bättre än att alltid gissa "över 2.5"**
# - Baseline (alltid gissa 1): 54% accuracy
# - Våra modeller: ~52% accuracy
# - Bayesian optimization förbättrade inte resultaten nämnvärt
#
# ### Brier Score ~0.25
# ❌ **Modellen är inte mer informativ än ett neutralt antagande på 50 %**
# - 0.25 = vad man får om man alltid säger 50/50
# - Modellen har ingen confidence i sina prediktioner
# - Hyperparameteroptimering gav minimal förbättring
#
# ### Precision@5
# ⚠️ **Lite bättre än slumpen, men instabilt**
# - Vid k=5 är detta väldigt känsligt för slump
# - Inte tillförlitligt nog för beslutsstöd
#
# ## Slutsats
#
# Trots användning av Bayesian optimization för att hitta optimala hyperparametrar presterar båda modellerna **mycket svagt**. Detta indikerar att problemet inte ligger i hyperparameterval utan i **attributens begränsade informationsinnehåll**.
#
# **Huvudsakliga slutsatser**:
# 1. De valda attributen (rullande medelvärden av mål, poäng, tidiga mål) räcker inte
# 2. Hyperparameteroptimering kan inte kompensera för svaga features
# 3. Fotbollsmatcher har hög inneboende slumpmässighet
#
# **Möjliga förklaringar**:
# 1. Saknar kritiska attribut (xG, taktik, skador, motivation)
# 2. Fotboll har hög grad av slumpmässighet som inte kan fångas av historisk statistik
# 3. Matchspecifika faktorer (väder, domare, taktisk matchning) saknas
# 4. Pre-match-statistik fångar inte "dagsform" eller psykologiska faktorer
#
# ## Nästa steg (vidare forskning)
#
# **Förbättring av features**:
# - Införa xG (Expected Goals) data
# - Lägga till spelartrupp och skadelistor
# - Inkludera taktiska indikatorer (pressning, bollinnehav)
# - Lägg till head-to-head statistik
#
# **Metodutveckling**:
# - Testa ensemble-metoder (stacking, blending)
# - Kalibrera sannolikheterna (Platt scaling, isotonic regression)
# - Utöka dataset med fler ligor för mer träningsdata
# - Testa deep learning-metoder (LSTM för temporal modellering)
#
# **Alternativa approaches**:
# - Poisson-baserade modeller för målfördelning
# - Bayesianska metoder för osäkerhetskvantifiering
# - Reinforcement learning för adaptiva prediktioner

# %%
import numpy as np
import pandas as pd

from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, brier_score_loss, roc_auc_score
from sklearn.linear_model import LogisticRegression


def precision_at_k(y_true, y_prob, k=5):
    y_true = np.asarray(y_true)
    y_prob = np.asarray(y_prob)
    k = min(k, len(y_true))
    topk_idx = np.argsort(-y_prob)[:k]
    return y_true[topk_idx].mean()

def evaluate_model(name, y_true, proba):
    pred = (proba >= 0.5).astype(int)
    return {
        "Model": name,
        "ROC_AUC": roc_auc_score(y_true, proba),
        "Accuracy": accuracy_score(y_true, pred),
        "Brier": brier_score_loss(y_true, proba),
        "Precision@5": precision_at_k(y_true, proba, k=5),
    }

# --- columns / target ---
y_col = "fulltime_over_2_5"
drop_cols = ["fixture_id", "date", "season", y_col]
X_cols = [c for c in df_pre_match.columns if c not in drop_cols]

# --- train/test split: last 2 seasons as test ---
test_seasons = sorted(df_pre_match["season"].unique())[-2:]

train_df = df_pre_match[~df_pre_match["season"].isin(test_seasons)].copy()
test_df  = df_pre_match[df_pre_match["season"].isin(test_seasons)].copy()

X_train, y_train = train_df[X_cols], train_df[y_col].astype(int)
X_test,  y_test  = test_df[X_cols],  test_df[y_col].astype(int)

print("Test seasons:", test_seasons)
print("Train rows:", len(train_df), " Test rows:", len(test_df))
print("Num features:", len(X_cols))
# Out:
# Test seasons: [np.int64(2023), np.int64(2024)]
# Train rows: 3018  Test rows: 758
# Num features: 18

# %% [markdown]
# ### Hyperparameteroptimering med BayesSearchCV
#
# Denna kod används för att optimera hyperparametrar för två klassificeringsmodeller: Random Forest och logistisk regression. Optimeringen genomförs med hjälp av BayesSearchCV, som använder bayesiansk optimering för att effektivt söka efter parametrar som ger bäst modellprestanda.
#
#
#
# För att hantera tidsberoende data används TimeSeriesSplit med tre delningar, vilket säkerställer att träningsdata alltid föregår valideringsdata i tiden och därmed förhindrar informationsläckage. För Random Forest optimeras bland annat antal träd, trädens djup och minsta antal observationer per nod, medan regulariseringsparametern optimeras för den logistiska regressionsmodellen.
#
#
#
# Som utvärderingsmått används negativt Brier score, vilket innebär att optimeringen prioriterar modeller som ger välkalibrerade sannolikhetsprediktioner. Efter avslutad optimering sparas den bästa modellen för respektive algoritm för vidare utvärdering på testdata.
#
#
#
# **Källa som inspirerade dennna del**:
# https://www.kaggle.com/discussions/general/523342

# %%
# !pip -q install scikit-optimize
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.8/107.8 kB 2.6 MB/s eta 0:00:00

# %%
from skopt import BayesSearchCV
from sklearn.model_selection import TimeSeriesSplit
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression

tscv = TimeSeriesSplit(n_splits=3)

# ---------------- Random Forest (Bayesian search) ----------------
rf_model = RandomForestClassifier(
    random_state=42,
    n_jobs=-1,
    class_weight="balanced",
)

rf_search_space = {
    "n_estimators": (150, 500),
    "max_depth": (3, 10),
    "min_samples_leaf": (10, 60),
    "min_samples_split": (10, 80),
    "max_features": ["sqrt", "log2"],
}

rf_bayes = BayesSearchCV(
    estimator=rf_model,
    search_spaces=rf_search_space,
    n_iter=30,
    cv=tscv,
    scoring="neg_brier_score",
    n_jobs=1,
    random_state=42,
    verbose=2,
)
rf_bayes.fit(X_train, y_train)

print("Best RF params:", rf_bayes.best_params_)
print("Best RF CV (neg brier):", rf_bayes.best_score_)

best_rf = rf_bayes.best_estimator_


# ---------------- Logistic Regression (Bayesian search) ----------------
lr_model = LogisticRegression(
    solver="lbfgs",
    max_iter=5000,
    class_weight="balanced",
)

lr_search_space = {
    "C": (1e-3, 10.0, "log-uniform"),
    "penalty": ["l2"],
}

lr_bayes = BayesSearchCV(
    estimator=lr_model,
    search_spaces=lr_search_space,
    n_iter=30,
    cv=tscv,
    scoring="neg_brier_score",
    n_jobs=1,
    random_state=42,
    verbose=2,
)
lr_bayes.fit(X_train, y_train)

print("Best LR params:", lr_bayes.best_params_)
print("Best LR CV (neg brier):", lr_bayes.best_score_)

best_lr = lr_bayes.best_estimator_
# Out:
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END max_depth=6, max_features=log2, min_samples_leaf=57, min_samples_split=32, n_estimators=385; total time=   1.5s
# [CV] END max_depth=6, max_features=log2, min_samples_leaf=57, min_samples_split=32, n_estimators=385; total time=   1.4s
# [CV] END max_depth=6, max_features=log2, min_samples_leaf=57, min_samples_split=32, n_estimators=385; total time=   2.4s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END max_depth=9, max_features=log2, min_samples_leaf=25, min_samples_split=77, n_estimators=452; total time=   2.0s
# [CV] END max_depth=9, max_features=log2, min_samples_leaf=25, min_samples_split=77, n_estimators=452; total time=   2.0s
# [CV] END max_depth=9, max_features=log2, min_samples_leaf=25, min_samples_split=77, n_estimators=452; total time=   2.2s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END max_depth=6, max_features=log2, min_samples_leaf=15, min_samples_split=40, n_estimators=216; total time=   1.0s
# [CV] END max_depth=6, max_features=log2, min_samples_leaf=15, min_samples_split=40, n_estimators=216; total time=   0.9s
# [CV] END max_depth=6, max_features=log2, min_samples_leaf=15, min_samples_split=40, n_estimators=216; total time=   0.9s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END max_depth=9, max_features=sqrt, min_samples_leaf=40, min_samples_split=66, n_estimators=333; total time=   1.1s
# [CV] END max_depth=9, max_features=sqrt, min_samples_leaf=40, min_samples_split=66, n_estimators=333; total time=   1.5s
# [CV] END max_depth=9, max_features=sqrt, min_samples_leaf=40, min_samples_split=66, n_estimators=333; total time=   1.7s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END max_depth=9, max_features=sqrt, min_samples_leaf=36, min_samples_split=60, n_estimators=466; total time=   1.6s
# [CV] END max_depth=9, max_features=sqrt, min_samples_leaf=36, min_samples_split=60, n_estimators=466; total time=   1.7s
# [CV] END max_depth=9, max_features=sqrt, min_samples_leaf=36, min_samples_split=60, n_estimators=466; total time=   2.3s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END max_depth=8, max_features=log2, min_samples_leaf=18, min_samples_split=23, n_estimators=430; total time=   1.6s
# [CV] END max_depth=8, max_features=log2, min_samples_leaf=18, min_samples_split=23, n_estimators=430; total time=   1.8s
# [CV] END max_depth=8, max_features=log2, min_samples_leaf=18, min_samples_split=23, n_estimators=430; total time=   2.6s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END max_depth=7, max_features=log2, min_samples_leaf=28, min_samples_split=71, n_estimators=357; total time=   1.4s
# [CV] END max_depth=7, max_features=log2, min_samples_leaf=28, min_samples_split=71, n_estimators=357; total time=   1.4s
# [CV] END max_depth=7, max_features=log2, min_samples_leaf=28, min_samples_split=71, n_estimators=357; total time=   1.5s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END max_depth=7, max_features=log2, min_samples_leaf=35, min_samples_split=69, n_estimators=263; total time=   1.2s
# [CV] END max_depth=7, max_features=log2, min_samples_leaf=35, min_samples_split=69, n_estimators=263; total time=   1.2s
# [CV] END max_depth=7, max_features=log2, min_samples_leaf=35, min_samples_split=69, n_estimators=263; total time=   1.1s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END max_depth=10, max_features=log2, min_samples_leaf=54, min_samples_split=39, n_estimators=283; total time=   1.1s
# [CV] END max_depth=10, max_features=log2, min_samples_leaf=54, min_samples_split=39, n_estimators=283; total time=   1.5s
# [CV] END max_depth=10, max_features=log2, min_samples_leaf=54, min_samples_split=39, n_estimators=283; total time=   1.6s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END max_depth=3, max_features=log2, min_samples_leaf=47, min_samples_split=28, n_estimators=353; total time=   1.7s
# [CV] END max_depth=3, max_features=log2, min_samples_leaf=47, min_samples_split=28, n_estimators=353; total time=   1.5s
# [CV] END max_depth=3, max_features=log2, min_samples_leaf=47, min_samples_split=28, n_estimators=353; total time=   2.0s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END max_depth=3, max_features=log2, min_samples_leaf=57, min_samples_split=80, n_estimators=474; total time=   2.6s
# [CV] END max_depth=3, max_features=log2, min_samples_leaf=57, min_samples_split=80, n_estimators=474; total time=   1.9s
# [CV] END max_depth=3, max_features=log2, min_samples_leaf=57, min_samples_split=80, n_estimators=474; total time=   2.0s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END max_depth=3, max_features=log2, min_samples_leaf=13, min_samples_split=79, n_estimators=164; total time=   1.0s
# [CV] END max_depth=3, max_features=log2, min_samples_leaf=13, min_samples_split=79, n_estimators=164; total time=   1.2s
# [CV] END max_depth=3, max_features=log2, min_samples_leaf=13, min_samples_split=79, n_estimators=164; total time=   0.9s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END max_depth=3, max_features=log2, min_samples_leaf=10, min_samples_split=13, n_estimators=459; total time=   2.2s
# [CV] END max_depth=3, max_features=log2, min_samples_leaf=10, min_samples_split=13, n_estimators=459; total time=   1.9s
# [CV] END max_depth=3, max_features=log2, min_samples_leaf=10, min_samples_split=13, n_estimators=459; total time=   2.0s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END max_depth=8, max_features=sqrt, min_samples_leaf=57, min_samples_split=39, n_estimators=330; total time=   1.6s
# [CV] END max_depth=8, max_features=sqrt, min_samples_leaf=57, min_samples_split=39, n_estimators=330; total time=   1.6s
# [CV] END max_depth=8, max_features=sqrt, min_samples_leaf=57, min_samples_split=39, n_estimators=330; total time=   2.1s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END max_depth=9, max_features=sqrt, min_samples_leaf=29, min_samples_split=47, n_estimators=324; total time=   1.3s
# [CV] END max_depth=9, max_features=sqrt, min_samples_leaf=29, min_samples_split=47, n_estimators=324; total time=   1.6s
# [CV] END max_depth=9, max_features=sqrt, min_samples_leaf=29, min_samples_split=47, n_estimators=324; total time=   1.6s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END max_depth=9, max_features=log2, min_samples_leaf=33, min_samples_split=30, n_estimators=345; total time=   1.4s
# [CV] END max_depth=9, max_features=log2, min_samples_leaf=33, min_samples_split=30, n_estimators=345; total time=   1.8s
# [CV] END max_depth=9, max_features=log2, min_samples_leaf=33, min_samples_split=30, n_estimators=345; total time=   1.7s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END max_depth=3, max_features=sqrt, min_samples_leaf=32, min_samples_split=76, n_estimators=499; total time=   2.0s
# [CV] END max_depth=3, max_features=sqrt, min_samples_leaf=32, min_samples_split=76, n_estimators=499; total time=   2.8s
# [CV] END max_depth=3, max_features=sqrt, min_samples_leaf=32, min_samples_split=76, n_estimators=499; total time=   2.6s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END max_depth=3, max_features=sqrt, min_samples_leaf=60, min_samples_split=32, n_estimators=261; total time=   1.1s
# [CV] END max_depth=3, max_features=sqrt, min_samples_leaf=60, min_samples_split=32, n_estimators=261; total time=   0.9s
# [CV] END max_depth=3, max_features=sqrt, min_samples_leaf=60, min_samples_split=32, n_estimators=261; total time=   1.1s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END max_depth=3, max_features=sqrt, min_samples_leaf=49, min_samples_split=80, n_estimators=153; total time=   0.7s
# [CV] END max_depth=3, max_features=sqrt, min_samples_leaf=49, min_samples_split=80, n_estimators=153; total time=   0.7s
# [CV] END max_depth=3, max_features=sqrt, min_samples_leaf=49, min_samples_split=80, n_estimators=153; total time=   0.7s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END max_depth=3, max_features=log2, min_samples_leaf=36, min_samples_split=80, n_estimators=463; total time=   3.0s
# [CV] END max_depth=3, max_features=log2, min_samples_leaf=36, min_samples_split=80, n_estimators=463; total time=   1.6s
# [CV] END max_depth=3, max_features=log2, min_samples_leaf=36, min_samples_split=80, n_estimators=463; total time=   2.2s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END max_depth=3, max_features=sqrt, min_samples_leaf=49, min_samples_split=10, n_estimators=491; total time=   2.1s
# [CV] END max_depth=3, max_features=sqrt, min_samples_leaf=49, min_samples_split=10, n_estimators=491; total time=   2.3s
# [CV] END max_depth=3, max_features=sqrt, min_samples_leaf=49, min_samples_split=10, n_estimators=491; total time=   2.4s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=18, n_estimators=316; total time=   1.5s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=18, n_estimators=316; total time=   1.7s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=18, n_estimators=316; total time=   2.0s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END max_depth=3, max_features=sqrt, min_samples_leaf=60, min_samples_split=80, n_estimators=239; total time=   1.2s
# [CV] END max_depth=3, max_features=sqrt, min_samples_leaf=60, min_samples_split=80, n_estimators=239; total time=   1.1s
# [CV] END max_depth=3, max_features=sqrt, min_samples_leaf=60, min_samples_split=80, n_estimators=239; total time=   1.0s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=45, min_samples_split=26, n_estimators=178; total time=   0.7s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=45, min_samples_split=26, n_estimators=178; total time=   0.7s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=45, min_samples_split=26, n_estimators=178; total time=   0.8s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END max_depth=3, max_features=log2, min_samples_leaf=40, min_samples_split=18, n_estimators=339; total time=   1.5s
# [CV] END max_depth=3, max_features=log2, min_samples_leaf=40, min_samples_split=18, n_estimators=339; total time=   1.2s
# [CV] END max_depth=3, max_features=log2, min_samples_leaf=40, min_samples_split=18, n_estimators=339; total time=   1.4s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END max_depth=8, max_features=log2, min_samples_leaf=39, min_samples_split=48, n_estimators=471; total time=   1.7s
# [CV] END max_depth=8, max_features=log2, min_samples_leaf=39, min_samples_split=48, n_estimators=471; total time=   1.9s
# [CV] END max_depth=8, max_features=log2, min_samples_leaf=39, min_samples_split=48, n_estimators=471; total time=   2.3s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=26, min_samples_split=72, n_estimators=431; total time=   2.6s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=26, min_samples_split=72, n_estimators=431; total time=   2.1s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=26, min_samples_split=72, n_estimators=431; total time=   2.1s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END max_depth=3, max_features=log2, min_samples_leaf=60, min_samples_split=10, n_estimators=150; total time=   1.3s
# [CV] END max_depth=3, max_features=log2, min_samples_leaf=60, min_samples_split=10, n_estimators=150; total time=   0.9s
# [CV] END max_depth=3, max_features=log2, min_samples_leaf=60, min_samples_split=10, n_estimators=150; total time=   0.9s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END max_depth=3, max_features=sqrt, min_samples_leaf=35, min_samples_split=10, n_estimators=150; total time=   0.7s
# [CV] END max_depth=3, max_features=sqrt, min_samples_leaf=35, min_samples_split=10, n_estimators=150; total time=   0.7s
# [CV] END max_depth=3, max_features=sqrt, min_samples_leaf=35, min_samples_split=10, n_estimators=150; total time=   0.8s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END max_depth=9, max_features=sqrt, min_samples_leaf=15, min_samples_split=57, n_estimators=483; total time=   2.0s
# [CV] END max_depth=9, max_features=sqrt, min_samples_leaf=15, min_samples_split=57, n_estimators=483; total time=   1.9s
# [CV] END max_depth=9, max_features=sqrt, min_samples_leaf=15, min_samples_split=57, n_estimators=483; total time=   2.1s
# Best RF params: OrderedDict({'max_depth': 3, 'max_features': 'log2', 'min_samples_leaf': 60, 'min_samples_split': 10, 'n_estimators': 150})
# Best RF CV (neg brier): -0.2500784444943567
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END ..................C=0.04369339947510315, penalty=l2; total time=   0.2s
# [CV] END ..................C=0.04369339947510315, penalty=l2; total time=   0.3s
# [CV] END ..................C=0.04369339947510315, penalty=l2; total time=   0.3s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END ...................C=2.2364202820542705, penalty=l2; total time=   0.3s
# [CV] END ...................C=2.2364202820542705, penalty=l2; total time=   0.4s
# [CV] END ...................C=2.2364202820542705, penalty=l2; total time=   0.4s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END .................C=0.060163078295899286, penalty=l2; total time=   0.3s
# [CV] END .................C=0.060163078295899286, penalty=l2; total time=   0.4s
# [CV] END .................C=0.060163078295899286, penalty=l2; total time=   1.0s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END ...................C=1.7765766649807682, penalty=l2; total time=   1.6s
# [CV] END ...................C=1.7765766649807682, penalty=l2; total time=   0.8s
# [CV] END ...................C=1.7765766649807682, penalty=l2; total time=   0.8s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END ...................C=1.5783879853890563, penalty=l2; total time=   0.3s
# [CV] END ...................C=1.5783879853890563, penalty=l2; total time=   0.5s
# [CV] END ...................C=1.5783879853890563, penalty=l2; total time=   0.5s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END ...................C=0.8632012725909878, penalty=l2; total time=   0.3s
# [CV] END ...................C=0.8632012725909878, penalty=l2; total time=   0.3s
# [CV] END ...................C=0.8632012725909878, penalty=l2; total time=   0.5s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END ..................C=0.29397976202716886, penalty=l2; total time=   0.2s
# [CV] END ..................C=0.29397976202716886, penalty=l2; total time=   0.3s
# [CV] END ..................C=0.29397976202716886, penalty=l2; total time=   0.3s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END ..................C=0.14914622679778672, penalty=l2; total time=   0.2s
# [CV] END ..................C=0.14914622679778672, penalty=l2; total time=   0.3s
# [CV] END ..................C=0.14914622679778672, penalty=l2; total time=   0.3s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END ...................C=6.6360850776123375, penalty=l2; total time=   0.3s
# [CV] END ...................C=6.6360850776123375, penalty=l2; total time=   0.4s
# [CV] END ...................C=6.6360850776123375, penalty=l2; total time=   0.6s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END ................C=0.0010340016434251915, penalty=l2; total time=   0.0s
# [CV] END ................C=0.0010340016434251915, penalty=l2; total time=   0.1s
# [CV] END ................C=0.0010340016434251915, penalty=l2; total time=   0.1s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END ...................C=6.2090588927974615, penalty=l2; total time=   0.3s
# [CV] END ...................C=6.2090588927974615, penalty=l2; total time=   0.5s
# [CV] END ...................C=6.2090588927974615, penalty=l2; total time=   0.6s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END ..................C=0.18156085405124872, penalty=l2; total time=   0.2s
# [CV] END ..................C=0.18156085405124872, penalty=l2; total time=   0.7s
# [CV] END ..................C=0.18156085405124872, penalty=l2; total time=   1.5s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END .................C=0.003994277776599169, penalty=l2; total time=   0.1s
# [CV] END .................C=0.003994277776599169, penalty=l2; total time=   0.1s
# [CV] END .................C=0.003994277776599169, penalty=l2; total time=   0.1s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END ...................C=0.0988550838266335, penalty=l2; total time=   0.2s
# [CV] END ...................C=0.0988550838266335, penalty=l2; total time=   0.3s
# [CV] END ...................C=0.0988550838266335, penalty=l2; total time=   0.3s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END ..................C=0.08040956569940304, penalty=l2; total time=   0.2s
# [CV] END ..................C=0.08040956569940304, penalty=l2; total time=   0.3s
# [CV] END ..................C=0.08040956569940304, penalty=l2; total time=   0.3s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END ....................C=6.671051977383557, penalty=l2; total time=   0.3s
# [CV] END ....................C=6.671051977383557, penalty=l2; total time=   0.5s
# [CV] END ....................C=6.671051977383557, penalty=l2; total time=   0.5s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END ....................C=2.473350696218773, penalty=l2; total time=   0.2s
# [CV] END ....................C=2.473350696218773, penalty=l2; total time=   0.4s
# [CV] END ....................C=2.473350696218773, penalty=l2; total time=   0.4s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END ....................C=7.776381469223014, penalty=l2; total time=   0.3s
# [CV] END ....................C=7.776381469223014, penalty=l2; total time=   0.4s
# [CV] END ....................C=7.776381469223014, penalty=l2; total time=   0.5s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END ................C=0.0025866150229444324, penalty=l2; total time=   0.1s
# [CV] END ................C=0.0025866150229444324, penalty=l2; total time=   0.4s
# [CV] END ................C=0.0025866150229444324, penalty=l2; total time=   0.5s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END ................C=0.0030170448746556985, penalty=l2; total time=   0.0s
# [CV] END ................C=0.0030170448746556985, penalty=l2; total time=   0.1s
# [CV] END ................C=0.0030170448746556985, penalty=l2; total time=   0.1s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END ..................C=0.04081801148987769, penalty=l2; total time=   0.2s
# [CV] END ..................C=0.04081801148987769, penalty=l2; total time=   0.2s
# [CV] END ..................C=0.04081801148987769, penalty=l2; total time=   0.3s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END ................C=0.0017768643396935118, penalty=l2; total time=   0.0s
# [CV] END ................C=0.0017768643396935118, penalty=l2; total time=   0.1s
# [CV] END ................C=0.0017768643396935118, penalty=l2; total time=   0.1s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END ................C=0.0046216195035813186, penalty=l2; total time=   0.1s
# [CV] END ................C=0.0046216195035813186, penalty=l2; total time=   0.1s
# [CV] END ................C=0.0046216195035813186, penalty=l2; total time=   0.2s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END .................C=0.001213977786433903, penalty=l2; total time=   0.0s
# [CV] END .................C=0.001213977786433903, penalty=l2; total time=   0.1s
# [CV] END .................C=0.001213977786433903, penalty=l2; total time=   0.1s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END .................C=0.004665651173316645, penalty=l2; total time=   0.1s
# [CV] END .................C=0.004665651173316645, penalty=l2; total time=   0.1s
# [CV] END .................C=0.004665651173316645, penalty=l2; total time=   0.2s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END .................C=0.021827785441739946, penalty=l2; total time=   0.1s
# [CV] END .................C=0.021827785441739946, penalty=l2; total time=   0.2s
# [CV] END .................C=0.021827785441739946, penalty=l2; total time=   0.3s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END ................C=0.0037014625576040064, penalty=l2; total time=   0.1s
# [CV] END ................C=0.0037014625576040064, penalty=l2; total time=   0.1s
# [CV] END ................C=0.0037014625576040064, penalty=l2; total time=   0.2s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END .................C=0.003696701863440921, penalty=l2; total time=   0.1s
# [CV] END .................C=0.003696701863440921, penalty=l2; total time=   0.2s
# [CV] END .................C=0.003696701863440921, penalty=l2; total time=   0.3s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END ................C=0.0037018863624625168, penalty=l2; total time=   0.1s
# [CV] END ................C=0.0037018863624625168, penalty=l2; total time=   0.1s
# [CV] END ................C=0.0037018863624625168, penalty=l2; total time=   0.2s
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END .................C=0.003693679007233696, penalty=l2; total time=   0.1s
# [CV] END .................C=0.003693679007233696, penalty=l2; total time=   0.1s
# [CV] END .................C=0.003693679007233696, penalty=l2; total time=   0.1s
# Best LR params: OrderedDict({'C': 0.0037018863624625168, 'penalty': 'l2'})
# Best LR CV (neg brier): -0.24943744316864858

# %%
# ----- Train final models with BEST params -----

best_rf_params = rf_bayes.best_params_
best_lr_params = lr_bayes.best_params_

# Random Forest
rf = RandomForestClassifier(
    **best_rf_params,
    random_state=42,
    n_jobs=-1,
    class_weight="balanced",
)
rf.fit(X_train, y_train)

# Logistic Regression
lr = LogisticRegression(
    **best_lr_params,
    solver="lbfgs",
    max_iter=5000,
    class_weight="balanced",
)
lr.fit(X_train, y_train)

# ----- Predict on test -----
p_rf = rf.predict_proba(X_test)[:, 1]
p_lr = lr.predict_proba(X_test)[:, 1]

# ----- Results table -----
results_df = (
    pd.DataFrame([
        evaluate_model("RF (Bayes-opt)", y_test, p_rf),
        evaluate_model("LogReg (Bayes-opt)", y_test, p_lr),
    ])
    .set_index("Model")
    .round(3)
)

print("Models trained with Bayesian-optimized hyperparameters")
results_df
# Out:
# Models trained with Bayesian-optimized hyperparameters
#                     ROC_AUC  Accuracy  Brier  Precision@5
# Model
# RF (Bayes-opt)        0.506     0.504   0.25          1.0
# LogReg (Bayes-opt)    0.507     0.517   0.25          1.0
